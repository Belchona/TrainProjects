# %% [markdown]
# # Выявить определяющие успешность игры закономерности

# %% [markdown]
# ## Описание проекта
#
# Вы работаете в интернет-магазине, который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Не важно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».
# Инструкция по выполнению проекта
#
# ### Шаг 1. Откройте файл с данными и изучите общую информацию
# Путь к файлу: /datasets/games.csv.
#
# ### Шаг 2. Подготовьте данные
# * Замените названия столбцов (приведите к нижнему регистру);
# * Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
# * Обработайте пропуски при необходимости;
# * Обратите внимание на аббревиатуру 'tbd' в столбцах с рейтингом. Отдельно разберите это значение и опишите, как его обработать;
# * Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.
#
# ### Шаг 3. Проведите исследовательский анализ данных
# * Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# * Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
# * Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год. Не учитывайте в работе данные за предыдущие годы.
# * Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
# * Постройте график «ящик с усами» по глобальным продажам каждой игры и разбивкой по платформам. Велика ли разница в продажах? А в средних продажах на разных платформах? Опишите результат.
# * Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
# * Соотнесите выводы с продажами игр на других платформах.
# * Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
# ### Шаг 4. Составьте портрет пользователя каждого региона
# Определите для пользователя каждого региона (NA, EU, JP):
# Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# Самые популярные жанры (топ-5). Поясните разницу.
# Влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
# ### Шаг 5. Проверьте гипотезы
# Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# Средние пользовательские рейтинги жанров Action (англ. «действие») и Sports (англ. «виды спорта») разные.
# Задайте самостоятельно пороговое значение alpha.
# Поясните:
# Как вы сформулировали нулевую и альтернативную гипотезы;
# Какой критерий применили для проверки гипотез и почему.
#
# ### Шаг 6. Напишите общий вывод
# Оформление: Выполните задание в Jupyter Notebook. Заполните программный код в ячейках типа code, текстовые пояснения — в ячейках типа markdown. Примените форматирование и заголовки.

# %% [markdown]
# ## Шаг 1. Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict
from scipy import stats as st
import seaborn as sns

# %%
games_data = pd.read_csv("https://code.s3.yandex.net/datasets/games.csv", sep=",") 
display(games_data)
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
#        NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score  \
# 0         41.36     28.96      3.77         8.45          76.0          8
# 1         29.08      3.58      6.81         0.77           NaN        NaN
# 2         15.68     12.76      3.79         3.29          82.0        8.3
# 3         15.61     10.93      3.28         2.95          80.0          8
# 4         11.27      8.89     10.22         1.00           NaN        NaN
# ...         ...       ...       ...          ...           ...        ...
# 16710      0.00      0.00      0.01         0.00           NaN        NaN
# 16711      0.00      0.01      0.00         0.00           NaN        NaN
# 16712      0.00      0.00      0.01         0.00           NaN        NaN
# 16713      0.01      0.00      0.00         0.00           NaN        NaN
# 16714      0.00      0.00      0.01         0.00           NaN        NaN
#
#       Rating
# 0          E
# 1        NaN
# 2          E
# 3          E
# 4        NaN
# ...      ...
# 16710    NaN
# 16711    NaN
# 16712    NaN
# 16713    NaN
# 16714    NaN
#
# [16715 rows x 11 columns]

# %%
games_data.describe()
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %% [markdown]
# ## Шаг 2. Подготовьте данные
# ### 		Замените названия столбцов (приведите к нижнему регистру);

# %%
games_data.columns = games_data.columns.str.lower()
games_data.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %% [markdown]
# ### 		Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;

# %%
games_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# name               16713 non-null object
# platform           16715 non-null object
# year_of_release    16446 non-null float64
# genre              16713 non-null object
# na_sales           16715 non-null float64
# eu_sales           16715 non-null float64
# jp_sales           16715 non-null float64
# other_sales        16715 non-null float64
# critic_score       8137 non-null float64
# user_score         10014 non-null object
# rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Преобразуем тип данных в годе релиза:
# - year_of_release - должно быть годом, или хотя бы int, а не float
# - user_score - должно быть float

# %% [markdown]
# ### Год выпуска понадобится для вычислений. Поэтому его потребуется преобразовать в int и заполнить пропуски

# %% [markdown]
# ### Посмотрим какие вообще значения года выпуска есть

# %%
games_data['year_of_release'].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2016., 2003., 1986., 2000.,   nan, 1995., 1991., 1981., 1987.,
#        1980., 1983.])

# %% [markdown]
# ### Есть nan в годе выпуска. Оценим сколько таких строк и какие там игры

# %%
games_nan_year = games_data.query('year_of_release == "  nan"')
games_nan_year
# Out:
#                                     name platform  year_of_release  \
# 183                      Madden NFL 2004      PS2              NaN
# 377                     FIFA Soccer 2004      PS2              NaN
# 456           LEGO Batman: The Videogame      Wii              NaN
# 475           wwe Smackdown vs. Raw 2006      PS2              NaN
# 609                       Space Invaders     2600              NaN
# ...                                  ...      ...              ...
# 16373  PDC World Championship Darts 2008      PSP              NaN
# 16405                      Freaky Flyers       GC              NaN
# 16448                          Inversion       PC              NaN
# 16458        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16522                       Virtua Quest       GC              NaN
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 183          Sports      4.26      0.26      0.01         0.71          94.0
# 377          Sports      0.59      2.36      0.04         0.51          84.0
# 456          Action      1.80      0.97      0.00         0.29          74.0
# 475        Fighting      1.57      1.02      0.00         0.41           NaN
# 609         Shooter      2.36      0.14      0.00         0.03           NaN
# ...             ...       ...       ...       ...          ...           ...
# 16373        Sports      0.01      0.00      0.00         0.00          43.0
# 16405        Racing      0.01      0.00      0.00         0.00          69.0
# 16448       Shooter      0.01      0.00      0.00         0.00          59.0
# 16458     Adventure      0.01      0.00      0.00         0.00           NaN
# 16522  Role-Playing      0.01      0.00      0.00         0.00          55.0
#
#       user_score rating
# 183          8.5      E
# 377          6.4      E
# 456          7.9   E10+
# 475          NaN    NaN
# 609          NaN    NaN
# ...          ...    ...
# 16373        tbd   E10+
# 16405        6.5      T
# 16448        6.7      M
# 16458        NaN    NaN
# 16522        5.5      T
#
# [269 rows x 11 columns]

# %% [markdown]
# ### 269 строк с незаполненным годом выпуска игры

# %%
len(games_nan_year['name'])
# Out:
# 269

# %% [markdown]
# ### И это 269 уникальных названий игр

# %% [markdown]
# ### Посмотрим названия

# %%
games_nan_year['name'].unique()
# Out:
# array(['Madden NFL 2004', 'FIFA Soccer 2004',
#        'LEGO Batman: The Videogame', 'wwe Smackdown vs. Raw 2006',
#        'Space Invaders', 'Rock Band',
#        "Frogger's Adventures: Temple of the Frog",
#        'LEGO Indiana Jones: The Original Adventures', 'Call of Duty 3',
#        'Call of Duty: Black Ops', 'Triple Play 99', 'Adventure', 'Combat',
#        'LEGO Harry Potter: Years 5-7', 'NASCAR Thunder 2003',
#        'Hitman 2: Silent Assassin', 'Legacy of Kain: Soul Reaver',
#        'Donkey Kong Land III', 'Air-Sea Battle', 'Suikoden III',
#        'Wheel of Fortune', 'Yakuza 4', 'Namco Museum', 'Rhythm Heaven',
#        'The Lord of the Rings: War in the North', 'Madden NFL 07',
#        'MLB SlugFest 20-03', 'Shaun White Snowboarding',
#        'PES 2009: Pro Evolution Soccer', 'WarioWare: Twisted!',
#        'Madden NFL 11', 'Test Drive Unlimited 2',
#        'The Chronicles of Narnia: The Lion, The Witch and The Wardrobe',
#        'Monster Hunter 2', 'Metal Gear Solid 2: Substance',
#        'Advance Wars: Days of Ruin', 'The Golden Compass',
#        'Madden NFL 06', 'NASCAR: Dirt to Daytona', 'Madden NFL 2002',
#        'Def Jam: Fight for NY', 'NBA Street Vol. 2', 'Fishing Derby',
#        'Wet', 'Sonic the Hedgehog', 'Karate', 'Tiger Woods PGA Tour 07',
#        'Circus Atari',
#        'The Chronicles of Riddick: Escape from Butcher Bay',
#        "Maze Craze: A Game of Cops 'n Robbers", 'Silent Hill: Homecoming',
#        'Super Breakout', "Robert Ludlum's The Bourne Conspiracy",
#        'NHL Slapshot', 'TERA', 'NFL GameDay 2003',
#        'Harvest Moon: Save the Homeland', 'Hangman', 'NBA Live 2003',
#        "Cubix Robots for Everyone: Clash 'n' Bash",
#        'Dragon Ball Z: Budokai Tenkaichi 2 (JP sales)', 'Tropico 4',
#        'Tomb Raider (2013)', 'Bejeweled 3', 'Custom Robo',
#        'Final Fantasy XI', 'Singularity', 'Dragster',
#        'All-Star Baseball 2005', 'Star Wars Jedi Knight II: Jedi Outcast',
#        'Slot Machine', 'The Dukes of Hazzard II: Daisy Dukes It Out',
#        'Harvest Moon: The Tale of Two Towns', 'Shrek the Third',
#        'Nicktoons: Battle for Volcano Island', 'Haven: Call of the King',
#        'Unreal Championship 2: The Liandri Conflict', 'Pac-Man Fever',
#        'The Legend of Zelda: The Minish Cap(weekly JP sales)', 'Indy 500',
#        'Disgaea 3: Absence of Detention', 'Flag Capture', 'Gun',
#        'Rock Revolution', 'College Hoops 2K6',
#        'Jonah Lomu Rugby Challenge', 'Mega Man X Collection',
#        'BioShock 2', 'Danganronpa: Trigger Happy Havoc', 'Jet X20',
#        "Tony Hawk's Downhill Jam", 'Tribes: Aerial Assault',
#        'Big Beach Sports 2', 'Yu Yu Hakusho: Dark Tournament',
#        'Ghostbusters II', 'Breakaway IV', 'Robotech: Battlecry',
#        'Move Fitness', 'Valkyria Chronicles III: Unrecorded Chronicles',
#        'DanceDanceRevolution II', 'WRC: FIA World Rally Championship',
#        'Famista 64', 'Dead Space 3', 'Pet Zombies', 'Star Trek: Legacy',
#        'Backbreaker', 'Twisted Metal: Small Brawl', 'Otomedius Excellent',
#        'NBA Starting Five', 'Teen Titans', 'Trauma Team',
#        "James Cameron's Dark Angel", 'Sword of the Samurai',
#        'Splatterhouse', 'Alone in the Dark: The New Nightmare',
#        'Vegas Party', 'Jurassic Park: The Game', 'Home Run',
#        'eJay Clubworld', 'Our House Party!', 'WCW Backstage Assault',
#        "Disney's Cinderella: Magical Dreams", 'Transworld Surf',
#        'Street Fighter IV', 'Nintendo Puzzle Collection',
#        'Charm Girls Club: My Fashion Mall', 'Record of Agarest War Zero',
#        'Rocksmith',
#        'Super Robot Wars OG Saga: Masou Kishin II - Revelation of Evil God',
#        'Saru! Get You! Million Monkeys', 'Street Hoops',
#        'Godzilla: Destroy All Monsters Melee',
#        'The Daring Game for Girls', 'Major League Baseball 2K6',
#        'Star Trek: Conquest', 'GiFTPiA', 'Happy Feet Two',
#        "Disney's Chicken Little: Ace In Action",
#        'Atsumare! Power Pro Kun no DS Koushien',
#        'My Healthy Cooking Coach', 'Luminous Arc 2 (JP sales)',
#        'Egg Monster Hero', 'Demon Chaos', 'Samurai Shodown Anthology',
#        'Action Man-Operation Extreme', 'Super Puzzle Fighter II',
#        'Charm Girls Club: My Fashion Show', 'Face Racers: Photo Finish',
#        'Zero: Tsukihami no Kamen', 'The Hidden', 'Get Fit with Mel B',
#        'Mega Man Battle Network: Operation Shooting Star',
#        'Smashing Drive', 'Port Royale 3', 'Dream Trigger 3D',
#        'Dead Island: Riptide', 'Yoostar on MTV', 'Tornado',
#        "McFarlane's Evil Prophecy", 'Drake of the 99 Dragons',
#        'Build-A-Bear Workshop: Friendship Valley', 'Rayman Arena',
#        'National Geographic Challenge!', 'Alex Rider: Stormbreaker',
#        'Chou Soujuu Mecha MG',
#        'Prinny: Can I Really Be The Hero? (US sales)',
#        'Combat Elite: WWII Paratroopers', "Flip's Twisted World",
#        'Mobile Ops: The One Year War',
#        "Tom Clancy's Rainbow Six: Critical Hour",
#        'Jewel Link Chronicles: Mountains of Madness',
#        'Captain America: Super Soldier', 'Mountain Bike Adrenaline',
#        'Drill Dozer', 'GRID', 'Tour de France 2011',
#        'Reader Rabbit 2nd Grade', 'Monster Hunter Frontier Online',
#        'RollerCoaster Tycoon', 'Battle vs. Chess',
#        'The History Channel: Great Battles - Medieval',
#        'Clockwork Empires', 'B.L.U.E.: Legend of Water', 'NHL Hitz Pro',
#        "Luxor: Pharaoh's Challenge", 'Sega Rally 2006',
#        'Half-Minute Hero 2', 'Housekeeping', 'Major League Baseball 2K8',
#        'Sabre Wulf', 'Swords', 'Beyond the Labyrinth',
#        'Bikkuriman Daijiten', 'Majesty 2: The Fantasy Kingdom Sim',
#        'Fullmetal Alchemist: Brotherhood',
#        'Samurai Spirits: Tenkaichi Kenkakuden', 'World of Tanks',
#        'Tom and Jerry in War of the Whiskers', 'Super Duper Sumos',
#        'The King of Fighters: Maximum Impact - Maniax',
#        'Combat Wings: The Great Battles of WWII', 'Tube Slider',
#        'Umineko no Naku Koro ni San: Shinjitsu to Gensou no Yasoukyoku',
#        'Payout Poker & Casino', 'Wii de Asobu: Metroid Prime',
#        'Legacy of Ys: Books I & II', 'Saint', 'Steal Princess',
#        'Mario Tennis', 'Runaway: A Twist of Fate',
#        "Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)",
#        "Cabela's Alaskan Adventure",
#        'Writing and Speaking Beautiful Japanese DS', 'Virtua Quest',
#        "Shonen Jump's Yu-Gi-Oh! GX Card Almanac", 'Without Warning',
#        'PDC World Championship Darts 2008',
#        'Dinotopia: The Sunstone Odyssey', 'Jet Impulse', 'Dream Dancer',
#        "Dance! It's Your Stage", 'Football Manager 2007',
#        'Ferrari: The Race Experience', 'Aquaman: Battle for Atlantis',
#        'Homeworld Remastered Collection', 'Shorts',
#        'AKB1/48: Idol to Guam de Koishitara...',
#        'Brothers in Arms: Furious 4', 'Agarest Senki: Re-appearance',
#        'Freaky Flyers', 'Inversion', 'Hakuouki: Shinsengumi Kitan'],
#       dtype=object)

# %% [markdown]
# ### В некоторых названиях содержится год выпуска игры. Это здорово, сможем заполнить ими год позже, если трудозатраты на обработку будут выглядеть оправданными.
# ### А пока заполним пропуски нулями, чтобы беспрепятственно конвертнуть тип в int64

# %%
games_data['year_of_release'] = games_data['year_of_release'].fillna('0')

# %%
games_data['year_of_release'] = games_data['year_of_release'].astype('int64')
games_data['year_of_release'].value_counts()
# Out:
# 2008    1427
# 2009    1426
# 2010    1255
# 2007    1197
# 2011    1136
# 2006    1006
# 2005     939
# 2002     829
# 2003     775
# 2004     762
# 2012     653
# 2015     606
# 2014     581
# 2013     544
# 2016     502
# 2001     482
# 1998     379
# 2000     350
# 1999     338
# 1997     289
# 0        269
# 1996     263
# 1995     219
# 1994     121
# 1993      62
# 1981      46
# 1992      43
# 1991      41
# 1982      36
# 1986      21
# 1989      17
# 1983      17
# 1990      16
# 1987      16
# 1988      15
# 1985      14
# 1984      14
# 1980       9
# Name: year_of_release, dtype: int64

# %% [markdown]
# ### 		Обработайте пропуски при необходимости:

# %%
games_data.isnull().sum().sort_values(ascending=False)
# Out:
# critic_score       8578
# rating             6766
# user_score         6701
# genre                 2
# name                  2
# other_sales           0
# jp_sales              0
# eu_sales              0
# na_sales              0
# year_of_release       0
# platform              0
# dtype: int64

# %% [markdown]
# ### Много пропусков в столбцах
# * critic_score -       8578
# * rating -             6766
# * user_score -         6701
#
# Их лучше заполнить, так как обработка данных потребует работы с рейтингом.
#
# ### Дважды пропущены данные в стобцах
# * genre -                 2
# * name -                 2
# Эти пропуски оставим без заполнения

# %% [markdown]
# ### Опишите причины, которые могли привести к пропускам;

# %% [markdown]
# ### critic_score, user_score и rating могли быть незаполнены по причинам:
# * игра старая, и в то время рейтинги еще не собирали
# * игра новая и не собрала рейтинги
# * игра еще не запущена
# * игра не набрала оценок для рейтинга

# %% [markdown]
# ### Объясните, почему заполнили пропуски определённым образом или почему не стали это делать

# %% [markdown]
# ### critic_score, user_score
# * Рейтинги critic_score, user_score можно заполнить средними значениями по очень точному срезу данных.
# * Я приму допущение что в среднем компания делаем в год по платформе и в жанре игры примерно с одним уровнем качества.
# * Для заполнения пропущенных значений в critic_score и user_score возьму их средние значения по вышеуказанному срезу.
# * Если в срезе не наберется данных для подсчета среднего, считаю, что у меня нет данных для заполнения рейтингов и оставлю их пустыми или удалю строки из массива в зависимости от их количества.
#
# ### raiting
# * Поле raiting содержит категориальные данные, значение которых мне не известно.
# * Вариант заполнения - погуглить и найти обозначение этих рейтингов, чтобы понять, можно ли посчитать некое "среднее" для заполнения пропущенных значений.
# * Если смысл рейтинга выяснить не удастся - оставлю его без заполнения
#
# ### Год
# * Поле неоднозначное. Просто вычислить среднее все же не вариант.
# * Пока нет идей как его заполнить, кроме как 0. Да, встречаются единичные значения названий игр с указанием года, но ручная обработка большого количества названий выглядит трудозатным занятием.

# %% [markdown]
# ### Обратите внимание на аббревиатуру 'tbd' в столбцах с рейтингом. Отдельно разберите это значение и опишите, как его обработать

# %% [markdown]
# TBD расшифровывается как будет объявлено позже.
# Чтобы понять как заменить его на какое-либо значение, нужно озакомиться с данными и проверить гипотезы о причинах незаполнения.
# Гипотезы о причинах те же, что и о пропусках в рейтинге:
# * игра старая, и в то время рейтинги еще не собирали
# * игра новая и не собрала рейтинги
# * игра еще не запущена
# * игра не набрала оценок для рейтинга

# %% [markdown]
# ## Посмотрю средний критик скор по жанрам и годам и платформам. Максимально точный срез для вычисления средних значений

# %%
games_data_critic_score_mean = games_data.pivot_table(
index = ('platform','year_of_release', 'genre'), values='critic_score', aggfunc=['mean'])
games_data_critic_score_mean = games_data_critic_score_mean.reset_index()
pd.set_option('display.max_rows', 151)
games_data_critic_score_mean
# Out:
#      platform year_of_release         genre         mean
#                                             critic_score
# 0         3DS               0        Action    71.000000
# 1         3DS               0       Shooter    54.000000
# 2         3DS            2011        Action    57.833333
# 3         3DS            2011     Adventure    58.333333
# 4         3DS            2011      Fighting    71.400000
# ...       ...             ...           ...          ...
# 1201     XOne            2016  Role-Playing    79.333333
# 1202     XOne            2016       Shooter    77.000000
# 1203     XOne            2016    Simulation    59.000000
# 1204     XOne            2016        Sports    81.500000
# 1205     XOne            2016      Strategy    87.000000
#
# [1206 rows x 4 columns]

# %% [markdown]
# ## Смерджу в новую таблицу основные данные и новое поле со средним critic score во все строки. И заполню этим средним отсутствующие значения critic score

# %%
games_data_grouped = (games_data
                      .merge(games_data_critic_score_mean, on=('platform', 'year_of_release', 'genre'),how='outer'))
games_data_grouped.reset_index()
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/reshape/merge.py:617: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py:3946: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   new_axis = axis.drop(labels, errors=errors)
#        index                                  name platform  year_of_release  \
# 0          0                            Wii Sports      Wii             2006
# 1          1            Rapala Tournament Fishing!      Wii             2006
# 2          2                         Madden NFL 07      Wii             2006
# 3          3                      Super Swing Golf      Wii             2006
# 4          4                     Super Mario Bros.      NES             1985
# ...      ...                                   ...      ...              ...
# 16710  16710  Mario vs. Donkey Kong: Tipping Stars     WiiU             2015
# 16711  16711                                  Ride     X360             2015
# 16712  16712                    Grand Prix Legends       PC             1997
# 16713  16713                Farming Simulator 2014      PSV             2014
# 16714  16714                   Winning Post 8 2016      PSV             2016
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 0          Sports     41.36     28.96      3.77         8.45          76.0
# 1          Sports      0.51      0.00      0.00         0.04           NaN
# 2          Sports      0.46      0.00      0.00         0.04          81.0
# 3          Sports      0.14      0.01      0.07         0.01          72.0
# 4        Platform     29.08      3.58      6.81         0.77           NaN
# ...           ...       ...       ...       ...          ...           ...
# 16710      Puzzle      0.00      0.00      0.01         0.00          70.0
# 16711      Racing      0.00      0.01      0.00         0.00           NaN
# 16712      Racing      0.00      0.01      0.00         0.00           NaN
# 16713  Simulation      0.01      0.00      0.00         0.00           NaN
# 16714  Simulation      0.00      0.00      0.01         0.00           NaN
#
#       user_score rating  (mean, critic_score)
# 0              8      E             76.333333
# 1            NaN    NaN             76.333333
# 2              8      E             76.333333
# 3            7.8   E10+             76.333333
# 4            NaN    NaN                   NaN
# ...          ...    ...                   ...
# 16710        7.4      E             70.000000
# 16711        NaN    NaN                   NaN
# 16712        7.5      E                   NaN
# 16713        NaN    NaN                   NaN
# 16714        NaN    NaN                   NaN
#
# [16715 rows x 13 columns]

# %%
games_data_grouped.columns
# Out:
# Index([                  'name',               'platform',
#               'year_of_release',                  'genre',
#                      'na_sales',               'eu_sales',
#                      'jp_sales',            'other_sales',
#                  'critic_score',             'user_score',
#                        'rating', ('mean', 'critic_score')],
#       dtype='object')

# %% [markdown]
# ## Количество строк также как в исходной таблице, ура-ура, мы ничего не потеряли. Продолжаем заполнять пустой критик скор этим средним

# %%
games_data_grouped = games_data_grouped.rename(columns={ ('mean', 'critic_score'): 'mean_critic_score'})
games_data_grouped.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating',
#        'mean_critic_score'],
#       dtype='object')

# %%
games_data_grouped['critic_score'] = games_data_grouped['critic_score'].fillna(games_data_grouped['mean_critic_score'])
games_data_grouped['critic_score'].isna().sum()
# Out:
# 2273

# %%
display(games_data_grouped)
# Out:
#                                        name platform  year_of_release  \
# 0                                Wii Sports      Wii             2006
# 1                Rapala Tournament Fishing!      Wii             2006
# 2                             Madden NFL 07      Wii             2006
# 3                          Super Swing Golf      Wii             2006
# 4                         Super Mario Bros.      NES             1985
# ...                                     ...      ...              ...
# 16710  Mario vs. Donkey Kong: Tipping Stars     WiiU             2015
# 16711                                  Ride     X360             2015
# 16712                    Grand Prix Legends       PC             1997
# 16713                Farming Simulator 2014      PSV             2014
# 16714                   Winning Post 8 2016      PSV             2016
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 0          Sports     41.36     28.96      3.77         8.45     76.000000
# 1          Sports      0.51      0.00      0.00         0.04     76.333333
# 2          Sports      0.46      0.00      0.00         0.04     81.000000
# 3          Sports      0.14      0.01      0.07         0.01     72.000000
# 4        Platform     29.08      3.58      6.81         0.77           NaN
# ...           ...       ...       ...       ...          ...           ...
# 16710      Puzzle      0.00      0.00      0.01         0.00     70.000000
# 16711      Racing      0.00      0.01      0.00         0.00           NaN
# 16712      Racing      0.00      0.01      0.00         0.00           NaN
# 16713  Simulation      0.01      0.00      0.00         0.00           NaN
# 16714  Simulation      0.00      0.00      0.01         0.00           NaN
#
#       user_score rating  mean_critic_score
# 0              8      E          76.333333
# 1            NaN    NaN          76.333333
# 2              8      E          76.333333
# 3            7.8   E10+          76.333333
# 4            NaN    NaN                NaN
# ...          ...    ...                ...
# 16710        7.4      E          70.000000
# 16711        NaN    NaN                NaN
# 16712        7.5      E                NaN
# 16713        NaN    NaN                NaN
# 16714        NaN    NaN                NaN
#
# [16715 rows x 12 columns]

# %% [markdown]
# ## Ура, пустых значений critic_score стало намного меньше!
# ## Метод работает, продолжим заполнять пустые значения в user_score
# ## Для начала надо привести тип к float, но код ругается на наличие строк в этом столбце. Это то самое значение tbd

# %%
games_data_grouped['user_score'].unique()
# Out:
# array(['8', nan, '7.8', '8.3', '8.1', '6.2', '6.3', '4.2', 'tbd', '5.7',
#        '7.1', '3.8', '2', '0.6', '4.3', '7.4', '8.7', '5.2', '8.8', '4.5',
#        '7.2', '8.4', '7.6', '8.6', '7.7', '6.8', '8.5', '7.5', '5.3',
#        '7.3', '6.4', '6.9', '6.6', '7.9', '6.1', '6', '7', '5.8', '5.4',
#        '0.7', '2.8', '8.2', '6.5', '3.7', '4.8', '5.9', '2.1', '9.1',
#        '4.1', '4.9', '5', '9', '9.3', '8.9', '6.7', '5.1', '9.5', '2.5',
#        '3.4', '3.9', '4.4', '4.7', '1.2', '3.6', '1.7', '5.5', '3.5',
#        '5.6', '3.2', '3.3', '3', '9.2', '2.7', '2.6', '4', '1.9', '1.5',
#        '9.4', '1.8', '2.4', '4.6', '3.1', '2.2', '1.6', '1', '0', '0.3',
#        '2.9', '1.1', '1.4', '2.3', '9.6', '0.2', '9.7', '0.9', '0.5',
#        '1.3'], dtype=object)

# %%
pd.set_option('display.max_rows', 151)
games_data_grouped['user_score'].value_counts()
# Out:
# tbd    2424
# 7.8     324
# 8       290
# 8.2     282
# 8.3     254
# 8.5     253
# 7.5     251
# 7.9     249
# 8.1     244
# 7.7     240
# 7.3     236
# 8.4     223
# 7.6     220
# 7       220
# 7.4     215
# 8.6     211
# 6.8     197
# 8.7     188
# 8.8     186
# 7.1     180
# 7.2     167
# 8.9     153
# 6.6     148
# 6.9     143
# 6.3     138
# 6.7     128
# 6       127
# 6.5     125
# 9       120
# 6.2     113
# 6.4     107
# 5.8      97
# 9.1      90
# 6.1      84
# 5.7      78
# 5.9      77
# 5.6      72
# 5.4      72
# 5.5      71
# 5.3      70
# 5        64
# 5.2      57
# 4.8      49
# 5.1      44
# 9.2      43
# 4.9      40
# 4.6      37
# 4.3      37
# 4.5      34
# 4.4      33
# 4.1      33
# 9.3      31
# 3.8      28
# 4.2      28
# 4        27
# 3.5      26
# 4.7      24
# 2.8      24
# 3.1      23
# 3.4      23
# 3        21
# 3.6      20
# 3.7      19
# 3.3      15
# 3.9      13
# 3.2      13
# 2.5      12
# 2.4      11
# 2        11
# 9.4      11
# 2.1       9
# 2.9       9
# 1.7       9
# 2.7       8
# 9.5       6
# 1.8       6
# 2.2       6
# 1.4       5
# 2.6       4
# 1.6       3
# 1.2       3
# 0.7       2
# 1.9       2
# 0.6       2
# 1.3       2
# 1.1       2
# 9.6       2
# 0.3       2
# 1.5       2
# 1         2
# 2.3       2
# 0.5       2
# 0.2       2
# 0.9       2
# 0         1
# 9.7       1
# Name: user_score, dtype: int64

# %% [markdown]
# ### Обработаем значение tbd в user_score

# %%
len(games_data_grouped[games_data_grouped.user_score == 'tbd'])
# Out:
# 2424

# %% [markdown]
# ## Сравним описание таблицы с user_score без значения tbd и с ним и поищем разницу

# %%
games_data_grouped_temp = games_data_grouped[games_data_grouped.user_score != 'tbd'].copy()
games_data_grouped_temp['user_score'] = games_data_grouped_temp['user_score'].astype('float64')
games_data_grouped_temp.describe()
# Out:
#        year_of_release      na_sales      eu_sales      jp_sales  \
# count     14291.000000  14291.000000  14291.000000  14291.000000
# mean       1975.295221      0.286670      0.162283      0.090320
# std         247.644844      0.874623      0.540532      0.332179
# min           0.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.030000      0.000000
# 75%        2011.000000      0.260000      0.130000      0.050000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         other_sales  critic_score   user_score  mean_critic_score
# count  14291.000000  12151.000000  7590.000000       12151.000000
# mean       0.052681     69.562646     7.125046          69.102480
# std        0.200815     12.147970     1.500006           7.856181
# min        0.000000     13.000000     0.000000          17.000000
# 25%        0.000000     62.600000     6.400000          64.428571
# 50%        0.010000     70.000000     7.500000          68.857143
# 75%        0.040000     78.000000     8.200000          73.750000
# max       10.570000     98.000000     9.700000          98.000000

# %%
games_data_grouped[games_data_grouped.user_score == 'tbd'].describe()
# Out:
#        year_of_release     na_sales     eu_sales     jp_sales  other_sales  \
# count      2424.000000  2424.000000  2424.000000  2424.000000  2424.000000
# mean       1967.698845     0.126052     0.043519     0.002727     0.015862
# std         279.755511     0.180586     0.111412     0.026136     0.039156
# min           0.000000     0.000000     0.000000     0.000000     0.000000
# 25%        2005.000000     0.030000     0.000000     0.000000     0.000000
# 50%        2008.000000     0.075000     0.010000     0.000000     0.010000
# 75%        2010.000000     0.150000     0.040000     0.000000     0.020000
# max        2016.000000     3.450000     2.590000     0.860000     1.090000
#
#        critic_score  mean_critic_score
# count   2291.000000        2291.000000
# mean      63.097727          65.538352
# std        9.214677           6.142763
# min       23.000000          40.333333
# 25%       58.428571          62.100000
# 50%       63.555556          65.000000
# 75%       69.414773          69.500000
# max       90.000000          86.000000

# %% [markdown]
# ## Отличия между описанием датасета без user_score = tbd и с user_score = tbd:
# * Средние значения продаж:
# na_sales 0.286670 vs 0.126052
# eu_sales 0.162283 vs 0.043519
# jp_sales 0.090320 vs 0.002727
# other_sales 0.052681 vs 0.015862
#
# При этом можно заметить, что средние critic_score так сильно не отличаются - 69.562646  vs 63.097727.
# ### Вывод. То есть игры с рейтингом tbd были выпущены, критики их оценили, а вот зрители - нет. И продажи таких игр ниже в 2-4 раза в разных странах. Сделаем предположение, что это непопулярные игры.
# ### Проставим им минимальный рейтинг по user_score из датасета без значения tbd.

# %%
games_data_user_score_mean = games_data_grouped_temp.pivot_table(
index = ('platform','year_of_release', 'genre'), values='user_score', aggfunc=['mean'])
games_data_user_score_mean = games_data_user_score_mean.reset_index()
pd.set_option('display.max_rows', 151)
games_data_user_score_mean
# Out:
#      platform year_of_release         genre       mean
#                                             user_score
# 0         3DS               0        Action   6.500000
# 1         3DS               0     Adventure   4.200000
# 2         3DS               0       Shooter   6.300000
# 3         3DS            2011        Action   5.929412
# 4         3DS            2011     Adventure   6.700000
# ...       ...             ...           ...        ...
# 1234     XOne            2016  Role-Playing   7.733333
# 1235     XOne            2016       Shooter   6.545455
# 1236     XOne            2016    Simulation   6.300000
# 1237     XOne            2016        Sports   6.120000
# 1238     XOne            2016      Strategy   8.100000
#
# [1239 rows x 4 columns]

# %%
games_data_grouped = (games_data_grouped
                      .merge(games_data_user_score_mean, on=('platform', 'year_of_release', 'genre'),how='outer'))
games_data_grouped.reset_index()
# Out:
#        index                                  name platform  year_of_release  \
# 0          0                            Wii Sports      Wii             2006
# 1          1            Rapala Tournament Fishing!      Wii             2006
# 2          2                         Madden NFL 07      Wii             2006
# 3          3                      Super Swing Golf      Wii             2006
# 4          4                     Super Mario Bros.      NES             1985
# ...      ...                                   ...      ...              ...
# 16710  16710  Mario vs. Donkey Kong: Tipping Stars     WiiU             2015
# 16711  16711                                  Ride     X360             2015
# 16712  16712                    Grand Prix Legends       PC             1997
# 16713  16713                Farming Simulator 2014      PSV             2014
# 16714  16714                   Winning Post 8 2016      PSV             2016
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 0          Sports     41.36     28.96      3.77         8.45     76.000000
# 1          Sports      0.51      0.00      0.00         0.04     76.333333
# 2          Sports      0.46      0.00      0.00         0.04     81.000000
# 3          Sports      0.14      0.01      0.07         0.01     72.000000
# 4        Platform     29.08      3.58      6.81         0.77           NaN
# ...           ...       ...       ...       ...          ...           ...
# 16710      Puzzle      0.00      0.00      0.01         0.00     70.000000
# 16711      Racing      0.00      0.01      0.00         0.00           NaN
# 16712      Racing      0.00      0.01      0.00         0.00           NaN
# 16713  Simulation      0.01      0.00      0.00         0.00           NaN
# 16714  Simulation      0.00      0.00      0.01         0.00           NaN
#
#       user_score rating  mean_critic_score  (mean, user_score)
# 0              8      E          76.333333            7.933333
# 1            NaN    NaN          76.333333            7.933333
# 2              8      E          76.333333            7.933333
# 3            7.8   E10+          76.333333            7.933333
# 4            NaN    NaN                NaN                 NaN
# ...          ...    ...                ...                 ...
# 16710        7.4      E          70.000000            7.400000
# 16711        NaN    NaN                NaN                 NaN
# 16712        7.5      E                NaN            7.500000
# 16713        NaN    NaN                NaN                 NaN
# 16714        NaN    NaN                NaN                 NaN
#
# [16715 rows x 14 columns]

# %%
games_data_grouped.columns
# Out:
# Index([                'name',             'platform',      'year_of_release',
#                       'genre',             'na_sales',             'eu_sales',
#                    'jp_sales',          'other_sales',         'critic_score',
#                  'user_score',               'rating',    'mean_critic_score',
#        ('mean', 'user_score')],
#       dtype='object')

# %%
games_data_grouped = games_data_grouped.rename(columns={ ('mean', 'user_score'): 'mean_user_score'})
games_data_grouped.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating',
#        'mean_critic_score', 'mean_user_score'],
#       dtype='object')

# %%
user_score_min = games_data_grouped['mean_user_score'].min()
user_score_min
# Out:
# 1.3

# %%
games_data_grouped['user_score'] = games_data_grouped['user_score'].replace('tbd',user_score_min)
len(games_data_grouped[games_data_grouped.user_score == 'tbd'])
# Out:
# 0

# %% [markdown]
# ### Пропущенные значения user_score заполним средними, вычисленными в таблице без tbd

# %%
games_data_grouped['user_score'] = games_data_grouped['user_score'].fillna(games_data_grouped['mean_user_score'])
games_data_grouped['user_score'].isna().sum()
# Out:
# 1920

# %% [markdown]
# ### Было незаполнено 6701 значений user_score и 2424 значений было заполнено как tbd.
# После обработки - 0 tbd и 1920 незаполненных значений user_score.
# Неплохой результат обработки.
#
# Посмотрим что же там осталось незаполненным

# %%
games_data_user_score_isna = games_data_grouped.query('user_score.isna()')
display(games_data_user_score_isna)
# Out:
#                              name platform  year_of_release         genre  \
# 4               Super Mario Bros.      NES             1985      Platform
# 5                     Ice Climber      NES             1985      Platform
# 6                   Balloon Fight      NES             1985      Platform
# 7                   Wrecking Crew      NES             1985      Platform
# 98       Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                           ...      ...              ...           ...
# 16704  Bakumatsu Rock: Ultra Soul      PSP             2014          Misc
# 16706                Turbo Trainz      Wii             2012        Racing
# 16711                        Ride     X360             2015        Racing
# 16713      Farming Simulator 2014      PSV             2014    Simulation
# 16714         Winning Post 8 2016      PSV             2016    Simulation
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# 4         29.08      3.58      6.81         0.77           NaN        NaN
# 5          0.46      0.10      0.92         0.02           NaN        NaN
# 6          0.39      0.09      0.43         0.01           NaN        NaN
# 7          0.00      0.00      0.51         0.00           NaN        NaN
# 98        11.27      8.89     10.22         1.00           NaN        NaN
# ...         ...       ...       ...          ...           ...        ...
# 16704      0.00      0.00      0.01         0.00           NaN        NaN
# 16706      0.00      0.01      0.00         0.00           NaN        NaN
# 16711      0.00      0.01      0.00         0.00           NaN        NaN
# 16713      0.01      0.00      0.00         0.00           NaN        NaN
# 16714      0.00      0.00      0.01         0.00           NaN        NaN
#
#       rating  mean_critic_score  mean_user_score
# 4        NaN                NaN              NaN
# 5        NaN                NaN              NaN
# 6        NaN                NaN              NaN
# 7        NaN                NaN              NaN
# 98       NaN                NaN              NaN
# ...      ...                ...              ...
# 16704    NaN                NaN              NaN
# 16706    NaN                NaN              NaN
# 16711    NaN                NaN              NaN
# 16713    NaN                NaN              NaN
# 16714    NaN                NaN              NaN
#
# [1920 rows x 13 columns]

# %%
games_data_user_score_isna.groupby(['platform'])['name'].count()
# Out:
# platform
# 2600    133
# 3DO       3
# 3DS      19
# DC       26
# DS       99
# GB       98
# GBA      14
# GC       10
# GEN      27
# GG        1
# N64     319
# NES      98
# NG       12
# PC       34
# PCFX      1
# PS      343
# PS2      49
# PS3      20
# PS4       2
# PSP     119
# PSV      23
# SAT     173
# SCD       6
# SNES    239
# TG16      2
# WS        6
# Wii      19
# WiiU      9
# X360      6
# XB        5
# XOne      3
# Name: name, dtype: int64

# %%
games_data_user_score_isna.groupby(['year_of_release'])['name'].count()
# Out:
# year_of_release
# 0        49
# 1980      9
# 1981     46
# 1982     36
# 1983     17
# 1984     14
# 1985     13
# 1986     21
# 1987     16
# 1988     14
# 1989     17
# 1990     16
# 1991     41
# 1992     42
# 1993     60
# 1994    119
# 1995    219
# 1996    193
# 1997    159
# 1998    146
# 1999    148
# 2000     91
# 2001     33
# 2002     16
# 2003     12
# 2004     15
# 2005      4
# 2006     14
# 2007      9
# 2008      6
# 2009     25
# 2010     45
# 2011     75
# 2012     58
# 2013     56
# 2014     27
# 2015     21
# 2016     16
# Name: name, dtype: int64

# %% [markdown]
# ### Можно отметить, что из оставшихся незаполненными значений user_score выделяются:
# * Топ-3 платформы, по которым много игр без пользовательского рейтинга:
# * N64     319
# * PS      343
# * SNES    239
# ---
# * Есть годы, за которые наблюдается более 100 игр без пользовательского рейтинга:
# * 1994    119
# * 1995    219
# * 1996    193
# * 1997    159
# * 1998    146
# * 1999    148
# ---
# Составлю прелположения:
# * либо эти платформы были непопулярны,
# * либо в диапазон лет с 1994 по 1999 были непопулярны игры вообще и / или игры этой компании в частности
# * либо пользователей не агитировали оставлять рейтинги по этим платформам / годам

# %% [markdown]
# ## Заполним пропуски в поле rating

# %%
games_data_rating_isna = games_data_grouped.query('rating.isna()')
display(games_data_rating_isna)
# Out:
#                                         name platform  year_of_release  \
# 1                 Rapala Tournament Fishing!      Wii             2006
# 4                          Super Mario Bros.      NES             1985
# 5                                Ice Climber      NES             1985
# 6                              Balloon Fight      NES             1985
# 7                              Wrecking Crew      NES             1985
# ...                                      ...      ...              ...
# 16706                           Turbo Trainz      Wii             2012
# 16709  Captain Morgane and the Golden Turtle      Wii             2012
# 16711                                   Ride     X360             2015
# 16713                 Farming Simulator 2014      PSV             2014
# 16714                    Winning Post 8 2016      PSV             2016
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 1          Sports      0.51      0.00      0.00         0.04     76.333333
# 4        Platform     29.08      3.58      6.81         0.77           NaN
# 5        Platform      0.46      0.10      0.92         0.02           NaN
# 6        Platform      0.39      0.09      0.43         0.01           NaN
# 7        Platform      0.00      0.00      0.51         0.00           NaN
# ...           ...       ...       ...       ...          ...           ...
# 16706      Racing      0.00      0.01      0.00         0.00           NaN
# 16709   Adventure      0.00      0.01      0.00         0.00           NaN
# 16711      Racing      0.00      0.01      0.00         0.00           NaN
# 16713  Simulation      0.01      0.00      0.00         0.00           NaN
# 16714  Simulation      0.00      0.00      0.01         0.00           NaN
#
#       user_score rating  mean_critic_score  mean_user_score
# 1        7.93333    NaN          76.333333         7.933333
# 4            NaN    NaN                NaN              NaN
# 5            NaN    NaN                NaN              NaN
# 6            NaN    NaN                NaN              NaN
# 7            NaN    NaN                NaN              NaN
# ...          ...    ...                ...              ...
# 16706        NaN    NaN                NaN              NaN
# 16709        1.3    NaN                NaN              NaN
# 16711        NaN    NaN                NaN              NaN
# 16713        NaN    NaN                NaN              NaN
# 16714        NaN    NaN                NaN              NaN
#
# [6766 rows x 13 columns]

# %%
games_data_grouped['rating'].unique()
# Out:
# array(['E', nan, 'E10+', 'T', 'M', 'EC', 'K-A', 'AO', 'RP'], dtype=object)

# %% [markdown]
# ### Нагуглено следующее значение рейтингов ESRB:
# «E» («Everyone») — «Для всех»
# "E10+» («Everyone 10 and older») — «Для всех от 10 лет и старше»
# «T» («Teen») — «Подросткам»
# «M» («Mature») — «Для взрослых»
# «EC» («Early childhood») — «Для детей младшего возраста»
# «AO» («Adults Only 18+») — «Только для взрослых»
# «RP» («Rating Pending») — «Рейтинг ожидается»
# 'K-A' This rating was known as Kids to Adults (K-A) until 1998, when it was renamed "Everyone".
#
# Так как выводить некие средние для контента игр не выглядит рабочим вариантом, предложу 2 способа заполнить пропуски:
# 1. Присвоить рейтинг «RP» («Rating Pending») — «Рейтинг ожидается», но тогда принимать во внимание, что в дальнейшем анализе это значение рейтинга не может принимать учатие. Во всяком случае, выводов по этому значению делать нельзя
# 2. Присвоить самый жесткий рейтинг и AO. Но этот способ считаю менее правильным - все же влияние жесткого рейтинга может быть интересно для анализа задачи.
# ---
# ### Поэтому выбираю первый вариант - заполняем пропуски rating значением «RP» («Rating Pending») — «Рейтинг ожидается»

# %%
games_data_grouped['rating'] = games_data_grouped['rating'].fillna('RP')
games_data_grouped['rating'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### 		Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.

# %%
games_data_grouped['total_sales'] = games_data_grouped['eu_sales'] + games_data_grouped['jp_sales'] + games_data_grouped['jp_sales']

# %%
games_data_grouped.sort_values(by='total_sales', ascending=False)
# Out:
#                                             name platform  year_of_release  \
# 0                                     Wii Sports      Wii             2006
# 98                      Pokemon Red/Pokemon Blue       GB             1996
# 103                        New Super Mario Bros.       DS             2006
# 155                  Pokemon Gold/Pokemon Silver       GB             1999
# 8                                 Mario Kart Wii      Wii             2008
# ...                                          ...      ...              ...
# 7951   Greg Hastings' Tournament Paintball Max'd      PS2             2006
# 14325                WWE SmackDown! vs. RAW 2006      PSP             2005
# 14326     Marvel Nemesis: Rise of the Imperfects      PSP             2005
# 14327                                    The Con      PSP             2005
# 2626                            Kao the Kangaroo      GBA             2001
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 0            Sports     41.36     28.96      3.77         8.45          76.0
# 98     Role-Playing     11.27      8.89     10.22         1.00           NaN
# 103        Platform     11.28      9.14      6.50         2.88          89.0
# 155    Role-Playing      9.00      6.18      7.20         0.71           NaN
# 8            Racing     15.68     12.76      3.79         3.29          82.0
# ...             ...       ...       ...       ...          ...           ...
# 7951        Shooter      0.01      0.00      0.00         0.00          70.0
# 14325      Fighting      0.36      0.00      0.00         0.03          81.0
# 14326      Fighting      0.29      0.00      0.00         0.02          58.0
# 14327      Fighting      0.18      0.00      0.00         0.02          63.0
# 2626       Platform      0.01      0.00      0.00         0.00          52.0
#
#       user_score rating  mean_critic_score  mean_user_score  total_sales
# 0              8      E          76.333333         7.933333        36.50
# 98           NaN     RP                NaN              NaN        29.33
# 103          8.5      E          72.363636         7.555556        22.14
# 155          NaN     RP                NaN              NaN        20.58
# 8            8.3      E          49.500000         5.592308        20.34
# ...          ...    ...                ...              ...          ...
# 7951         9.2   E10+          59.769231         7.308333         0.00
# 14325        8.5      T          67.333333         8.166667         0.00
# 14326        8.7      T          67.333333         8.166667         0.00
# 14327        7.3      T          67.333333         8.166667         0.00
# 2626         1.3      E          73.615385         7.914286         0.00
#
# [16715 rows x 14 columns]

# %% [markdown]
# ## Шаг 3. Проведите исследовательский анализ данных
# 1. Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# 2. Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
# 3. Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год. Не учитывайте в работе данные за предыдущие годы.
# 4. Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
# 5. Постройте график «ящик с усами» по глобальным продажам каждой игры и разбивкой по платформам. Велика ли разница в продажах? А в средних продажах на разных платформах? Опишите результат.
# 6. Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
# 7. Соотнесите выводы с продажами игр на других платформах.
# 8. Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %% [markdown]
# ### 3.1. Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %%
games_data_grouped.groupby(['year_of_release'])['name'].count()
games_data_year_importancy = games_data_grouped.pivot_table(
index = ('year_of_release'), values='name', aggfunc=['count'])

# %%
games_data_year_importancy = games_data_year_importancy.reset_index()
pd.set_option('display.max_rows', 151)
games_data_year_importancy
# Out:
#    year_of_release count
#                     name
# 0                0   269
# 1             1980     9
# 2             1981    46
# 3             1982    36
# 4             1983    17
# 5             1984    14
# 6             1985    14
# 7             1986    21
# 8             1987    16
# 9             1988    15
# 10            1989    17
# 11            1990    16
# 12            1991    41
# 13            1992    43
# 14            1993    60
# 15            1994   121
# 16            1995   219
# 17            1996   263
# 18            1997   289
# 19            1998   379
# 20            1999   338
# 21            2000   350
# 22            2001   482
# 23            2002   829
# 24            2003   775
# 25            2004   762
# 26            2005   939
# 27            2006  1006
# 28            2007  1197
# 29            2008  1427
# 30            2009  1426
# 31            2010  1255
# 32            2011  1136
# 33            2012   653
# 34            2013   544
# 35            2014   581
# 36            2015   606
# 37            2016   502

# %%
games_data_year_importancy.columns
# Out:
# MultiIndex([('year_of_release',     ''),
#             (          'count', 'name')],
#            )

# %%
games_data_year_importancy.columns=['year_of_release', 'name_count']
games_data_year_importancy['year_of_release'] =games_data_year_importancy['year_of_release'].astype('int64')
games_data_year_importancy['name_count'] =games_data_year_importancy['name_count'].astype('int64')
games_data_year_importancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 2 columns):
# year_of_release    38 non-null int64
# name_count         38 non-null int64
# dtypes: int64(2)
# memory usage: 736.0 bytes

# %%
games_data_year_importancy = games_data_year_importancy[games_data_year_importancy.year_of_release >1]

# %%
games_data_year_importancy.plot(kind='scatter', y='name_count', x='year_of_release')
plt.show()

# %% [markdown]
# ### Значительный прирост игр можно отметить с 1998 года

# %% [markdown]
# # Видимо, по условиям задачи нужно вырезать  данные за годы ранее 1998 из датасета. Вырезаем

# %%
games_data_grouped = games_data_grouped[games_data_grouped.year_of_release >= 1998]
games_data_grouped
# Out:
#                                         name platform  year_of_release  \
# 0                                 Wii Sports      Wii             2006
# 1                 Rapala Tournament Fishing!      Wii             2006
# 2                              Madden NFL 07      Wii             2006
# 3                           Super Swing Golf      Wii             2006
# 8                             Mario Kart Wii      Wii             2008
# ...                                      ...      ...              ...
# 16709  Captain Morgane and the Golden Turtle      Wii             2012
# 16710   Mario vs. Donkey Kong: Tipping Stars     WiiU             2015
# 16711                                   Ride     X360             2015
# 16713                 Farming Simulator 2014      PSV             2014
# 16714                    Winning Post 8 2016      PSV             2016
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 0          Sports     41.36     28.96      3.77         8.45     76.000000
# 1          Sports      0.51      0.00      0.00         0.04     76.333333
# 2          Sports      0.46      0.00      0.00         0.04     81.000000
# 3          Sports      0.14      0.01      0.07         0.01     72.000000
# 8          Racing     15.68     12.76      3.79         3.29     82.000000
# ...           ...       ...       ...       ...          ...           ...
# 16709   Adventure      0.00      0.01      0.00         0.00           NaN
# 16710      Puzzle      0.00      0.00      0.01         0.00     70.000000
# 16711      Racing      0.00      0.01      0.00         0.00           NaN
# 16713  Simulation      0.01      0.00      0.00         0.00           NaN
# 16714  Simulation      0.00      0.00      0.01         0.00           NaN
#
#       user_score rating  mean_critic_score  mean_user_score  total_sales
# 0              8      E          76.333333         7.933333        36.50
# 1        7.93333     RP          76.333333         7.933333         0.00
# 2              8      E          76.333333         7.933333         0.00
# 3            7.8   E10+          76.333333         7.933333         0.15
# 8            8.3      E          49.500000         5.592308        20.34
# ...          ...    ...                ...              ...          ...
# 16709        1.3     RP                NaN              NaN         0.01
# 16710        7.4      E          70.000000         7.400000         0.02
# 16711        NaN     RP                NaN              NaN         0.01
# 16713        NaN     RP                NaN              NaN         0.00
# 16714        NaN     RP                NaN              NaN         0.02
#
# [15187 rows x 14 columns]

# %% [markdown]
# ## 3.2. Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
# ## Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год. Не учитывайте в работе данные за предыдущие годы.

# %%
games_data_platform_sales = games_data_grouped.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')
games_data_platform_sales.reset_index()
# Out:
# platform  year_of_release    3DS    DC      DS     GB    GBA     GC    N64  \
# 0                    1998    NaN  3.47     NaN  26.10    NaN    NaN  23.43
# 1                    1999    NaN  6.63     NaN  32.41    NaN    NaN  26.82
# 2                    2000    NaN  5.87     NaN  20.24   0.02    NaN  21.03
# 3                    2001    NaN  2.14     NaN  10.97  30.84  12.50   1.58
# 4                    2002    NaN  0.58     NaN    NaN  41.54  21.05   0.02
# 5                    2003    NaN   NaN     NaN    NaN  30.37  23.09    NaN
# 6                    2004    NaN   NaN   11.23    NaN  45.19  11.33    NaN
# 7                    2005    NaN   NaN  101.21    NaN  14.85  10.27    NaN
# 8                    2006    NaN   NaN  100.19    NaN   4.00   2.70    NaN
# 9                    2007    NaN  0.04   87.41    NaN   0.90   0.06    NaN
# 10                   2008    NaN  0.08   80.26    NaN    NaN    NaN    NaN
# 11                   2009    NaN   NaN   74.25    NaN    NaN    NaN    NaN
# 12                   2010    NaN   NaN   58.54    NaN    NaN    NaN    NaN
# 13                   2011  44.29   NaN   14.35    NaN    NaN    NaN    NaN
# 14                   2012  51.64   NaN   10.12    NaN    NaN    NaN    NaN
# 15                   2013  61.98   NaN    0.85    NaN    NaN    NaN    NaN
# 16                   2014  50.11   NaN     NaN    NaN    NaN    NaN    NaN
# 17                   2015  36.10   NaN     NaN    NaN    NaN    NaN    NaN
# 18                   2016  18.39   NaN     NaN    NaN    NaN    NaN    NaN
#
# platform     PC      PS  ...    PSP    PSV   SAT  SNES    WS    Wii   WiiU  \
# 0          0.20  105.70  ...    NaN    NaN  7.64  0.44   NaN    NaN    NaN
# 1          1.13   98.74  ...    NaN    NaN  0.18  0.52  0.92    NaN    NaN
# 2          1.45   59.75  ...    NaN    NaN   NaN   NaN  1.36    NaN    NaN
# 3          1.24   21.44  ...    NaN    NaN   NaN   NaN  0.56    NaN    NaN
# 4          3.18    5.17  ...    NaN    NaN   NaN   NaN   NaN    NaN    NaN
# 5          4.92    0.78  ...    NaN    NaN   NaN   NaN   NaN    NaN    NaN
# 6          7.70     NaN  ...   5.76    NaN   NaN   NaN   NaN    NaN    NaN
# 7          2.69     NaN  ...  16.15    NaN   NaN   NaN   NaN    NaN    NaN
# 8          1.94     NaN  ...  22.70    NaN   NaN   NaN   NaN  61.92    NaN
# 9          6.21     NaN  ...  25.64    NaN   NaN   NaN   NaN  68.20    NaN
# 10         9.85     NaN  ...  28.11    NaN   NaN   NaN   NaN  71.90    NaN
# 11        13.50     NaN  ...  27.03    NaN   NaN   NaN   NaN  91.45    NaN
# 12        12.12     NaN  ...  42.14    NaN   NaN   NaN   NaN  53.87    NaN
# 13        18.94     NaN  ...  28.49   3.31   NaN   NaN   NaN  28.84    NaN
# 14        12.40     NaN  ...  14.61  10.16   NaN   NaN   NaN  12.67   9.54
# 15         7.39     NaN  ...   6.03  10.67   NaN   NaN   NaN   3.44  13.84
# 16         8.87     NaN  ...   0.48  14.71   NaN   NaN   NaN   1.86  13.04
# 17         5.57     NaN  ...   0.24  10.39   NaN   NaN   NaN   0.62  11.91
# 18         3.53     NaN  ...    NaN   7.51   NaN   NaN   NaN   0.11   2.82
#
# platform   X360     XB   XOne
# 0           NaN    NaN    NaN
# 1           NaN    NaN    NaN
# 2           NaN   0.21    NaN
# 3           NaN   5.39    NaN
# 4           NaN  12.76    NaN
# 5           NaN  14.09    NaN
# 6           NaN  15.02    NaN
# 7          0.99  12.53    NaN
# 8         13.24   2.25    NaN
# 9         25.21   0.12    NaN
# 10        41.94   0.04    NaN
# 11        37.21    NaN    NaN
# 12        50.53    NaN    NaN
# 13        46.14    NaN    NaN
# 14        34.12    NaN    NaN
# 15        27.89    NaN   5.38
# 16        11.44    NaN  18.43
# 17         3.50    NaN  18.81
# 18         0.71    NaN   9.65
#
# [19 rows x 23 columns]

# %%
games_data_platform_sales.columns
# Out:
# Index(['3DS', 'DC', 'DS', 'GB', 'GBA', 'GC', 'N64', 'PC', 'PS', 'PS2', 'PS3',
#        'PS4', 'PSP', 'PSV', 'SAT', 'SNES', 'WS', 'Wii', 'WiiU', 'X360', 'XB',
#        'XOne'],
#       dtype='object', name='platform')

# %%
games_data_platform_sales_filter = games_data_platform_sales.describe().loc['max'].sort_values(ascending=False).head(10)
games_data_platform_sales_filter
# Out:
# platform
# PS2     108.97
# PS      105.70
# DS      101.21
# Wii      91.45
# PS3      84.44
# PS4      64.38
# 3DS      61.98
# X360     50.53
# GBA      45.19
# PSP      42.14
# Name: max, dtype: float64

# %%
sales_mean = games_data_platform_sales.describe().loc['max'].mean()
sales_mean
# Out:
# 42.535454545454556

# %%
platforms_list = pd.Series(['PS2','PS','DS','Wii','PS3','PS4','3DS','X360','GBA','PSP'])

# %%
games_data_platform_sales_filtered = games_data_grouped.query('platform in @platforms_list').pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')
games_data_platform_sales_filtered.reset_index()
# Out:
# platform  year_of_release    3DS      DS    GBA      PS     PS2    PS3    PS4  \
# 0                    1998    NaN     NaN    NaN  105.70     NaN    NaN    NaN
# 1                    1999    NaN     NaN    NaN   98.74     NaN    NaN    NaN
# 2                    2000    NaN     NaN   0.02   59.75   28.38    NaN    NaN
# 3                    2001    NaN     NaN  30.84   21.44   87.95    NaN    NaN
# 4                    2002    NaN     NaN  41.54    5.17  108.97    NaN    NaN
# 5                    2003    NaN     NaN  30.37    0.78   98.96    NaN    NaN
# 6                    2004    NaN   11.23  45.19     NaN   94.35    NaN    NaN
# 7                    2005    NaN  101.21  14.85     NaN   70.96    NaN    NaN
# 8                    2006    NaN  100.19   4.00     NaN   56.89   9.54    NaN
# 9                    2007    NaN   87.41   0.90     NaN   30.07  34.54    NaN
# 10                   2008    NaN   80.26    NaN     NaN   19.09  50.37    NaN
# 11                   2009    NaN   74.25    NaN     NaN    8.82  59.46    NaN
# 12                   2010    NaN   58.54    NaN     NaN    2.96  70.24    NaN
# 13                   2011  44.29   14.35    NaN     NaN    0.31  84.44    NaN
# 14                   2012  51.64   10.12    NaN     NaN     NaN  62.93    NaN
# 15                   2013  61.98    0.85    NaN     NaN     NaN  66.53  12.93
# 16                   2014  50.11     NaN    NaN     NaN     NaN  30.74  52.44
# 17                   2015  36.10     NaN    NaN     NaN     NaN  13.38  64.38
# 18                   2016  18.39     NaN    NaN     NaN     NaN   3.86  43.26
#
# platform    PSP    Wii   X360
# 0           NaN    NaN    NaN
# 1           NaN    NaN    NaN
# 2           NaN    NaN    NaN
# 3           NaN    NaN    NaN
# 4           NaN    NaN    NaN
# 5           NaN    NaN    NaN
# 6          5.76    NaN    NaN
# 7         16.15    NaN   0.99
# 8         22.70  61.92  13.24
# 9         25.64  68.20  25.21
# 10        28.11  71.90  41.94
# 11        27.03  91.45  37.21
# 12        42.14  53.87  50.53
# 13        28.49  28.84  46.14
# 14        14.61  12.67  34.12
# 15         6.03   3.44  27.89
# 16         0.48   1.86  11.44
# 17         0.24   0.62   3.50
# 18          NaN   0.11   0.71

# %%
games_data_platform_sales_filtered.plot(kind='area', stacked=False, figsize=(15,10))
plt.show()

# %% [markdown]
# ## Вывод из графика:
# ### Средний срок жизни платформы - от 7 до 12 лет:
# * 1999-2011 (12 лет)
# * 2000 - 2007 (7 лет)
# * дважды - 2003-2014 (11 лет)
# * 2004-2014 (10 лет)
# * 2005-2013 (8 лет)
# * 2010-...
# * 2010-...

# %% [markdown]
# ## 3.3 Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.

# %% [markdown]
# Лидируют по продажам на промежутке времени с 1998 года по 2016:
# * PS
# * PS2
# * DS
# * Wii
# * PS3
#
# Падают на конец 2016:
# * 3DS
# * PS3
# * PS4
# * Wii
# * X360
#
# Растущих платформ нет
#
# Потенциально прибыльные платформы с остаточной прибылью:
# * 3DS
# * PS4
# * еще немного прибыли можно получить с PS3

# %% [markdown]
# ## 3.4 Постройте график «ящик с усами» по глобальным продажам каждой игры и разбивкой по платформам. Велика ли разница в продажах? А в средних продажах на разных платформах? Опишите результат.

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.boxplot(data = games_data_platform_sales_filtered)
#plt.ylim(0, 500)
sns.boxplot(data=games_data_platform_sales_filtered, palette='rainbow', showfliers=False)
plt.show()

# %% [markdown]
# ### Велика ли разница в продажах?
# Да, разница есть.
# Можно выделить 4 крупные по продажам платформы:
# * PS
# * PS2
# * DS
# * Wii
#
# 3 платформы поменьше:
# * GBA
# * PS3
# * X360
#
# и 3 совсем маленькие платформы:
# * 3DS
# * PS4
# * PSP
#
#
# ### А в средних продажах на разных платформах?
# В средних продажах разница не так велика.
# В нижней части диапазона средних продаж находятся платформы:
# * GBA
# * PSP
# * Wii
# * X360
#
# В верхней части диапазона находится платформа DS
#
# Все остальные платформы в середине диапазона на близких друг к другу средних значениях продаж

# %% [markdown]
# ## 3.5 Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.

# %%
games_data_3DS_user_score_sales = games_data_grouped.query('platform == "3DS"')
games_data_3DS_user_score_sales
# Out:
#                                                     name platform  \
# 572                                  Pokemon X/Pokemon Y      3DS
# 573                                     Monster Hunter 4      3DS
# 574                                          Yokai Watch      3DS
# 575                            Mario & Luigi: Dream Team      3DS
# 576                                     Puzzle & Dragons      3DS
# ...                                                  ...      ...
# 16312   Nekketsu Kouha Kunio-Kun SP: Rantou Kyousoukyoku      3DS
# 16346                                      E.X. Troopers      3DS
# 16448                                    Culdcept Revolt      3DS
# 16451  SpongeBob SquarePants: Plankton's Robotic Revenge      3DS
# 16636                     One Piece: Daikaizoku Coliseum      3DS
#
#        year_of_release         genre  na_sales  eu_sales  jp_sales  \
# 572               2013  Role-Playing      5.28      4.19      4.35
# 573               2013  Role-Playing      0.00      0.00      3.44
# 574               2013  Role-Playing      0.25      0.45      1.33
# 575               2013  Role-Playing      0.89      0.58      0.46
# 576               2013  Role-Playing      0.00      0.00      1.51
# ...                ...           ...       ...       ...       ...
# 16312             2013      Fighting      0.00      0.00      0.03
# 16346             2012       Shooter      0.00      0.00      0.07
# 16448             2016      Strategy      0.00      0.00      0.06
# 16451             2013       Shooter      0.00      0.06      0.00
# 16636             2016      Fighting      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating  mean_critic_score  \
# 572           0.78          68.0       7.55     RP               68.0
# 573           0.00          68.0       7.55     RP               68.0
# 574           0.05          68.0       7.55     RP               68.0
# 575           0.14          68.0       7.55     RP               68.0
# 576           0.00          68.0       7.55     RP               68.0
# ...            ...           ...        ...    ...                ...
# 16312         0.00           NaN        NaN     RP                NaN
# 16346         0.00           NaN        NaN     RP                NaN
# 16448         0.00           NaN        NaN     RP                NaN
# 16451         0.00           NaN        1.3   E10+                NaN
# 16636         0.00           NaN        NaN     RP                NaN
#
#        mean_user_score  total_sales
# 572               7.55        12.89
# 573               7.55         6.88
# 574               7.55         3.11
# 575               7.55         1.50
# 576               7.55         3.02
# ...                ...          ...
# 16312              NaN         0.06
# 16346              NaN         0.14
# 16448              NaN         0.12
# 16451              NaN         0.06
# 16636              NaN         0.06
#
# [512 rows x 14 columns]

# %%
games_data_3DS_user_score_sales['user_score'].isna().sum()
games_data_3DS_user_score_sales['user_score'] = games_data_3DS_user_score_sales['user_score'].fillna(0)
games_data_3DS_user_score_sales
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                     name platform  \
# 572                                  Pokemon X/Pokemon Y      3DS
# 573                                     Monster Hunter 4      3DS
# 574                                          Yokai Watch      3DS
# 575                            Mario & Luigi: Dream Team      3DS
# 576                                     Puzzle & Dragons      3DS
# ...                                                  ...      ...
# 16312   Nekketsu Kouha Kunio-Kun SP: Rantou Kyousoukyoku      3DS
# 16346                                      E.X. Troopers      3DS
# 16448                                    Culdcept Revolt      3DS
# 16451  SpongeBob SquarePants: Plankton's Robotic Revenge      3DS
# 16636                     One Piece: Daikaizoku Coliseum      3DS
#
#        year_of_release         genre  na_sales  eu_sales  jp_sales  \
# 572               2013  Role-Playing      5.28      4.19      4.35
# 573               2013  Role-Playing      0.00      0.00      3.44
# 574               2013  Role-Playing      0.25      0.45      1.33
# 575               2013  Role-Playing      0.89      0.58      0.46
# 576               2013  Role-Playing      0.00      0.00      1.51
# ...                ...           ...       ...       ...       ...
# 16312             2013      Fighting      0.00      0.00      0.03
# 16346             2012       Shooter      0.00      0.00      0.07
# 16448             2016      Strategy      0.00      0.00      0.06
# 16451             2013       Shooter      0.00      0.06      0.00
# 16636             2016      Fighting      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating  mean_critic_score  \
# 572           0.78          68.0       7.55     RP               68.0
# 573           0.00          68.0       7.55     RP               68.0
# 574           0.05          68.0       7.55     RP               68.0
# 575           0.14          68.0       7.55     RP               68.0
# 576           0.00          68.0       7.55     RP               68.0
# ...            ...           ...        ...    ...                ...
# 16312         0.00           NaN          0     RP                NaN
# 16346         0.00           NaN          0     RP                NaN
# 16448         0.00           NaN          0     RP                NaN
# 16451         0.00           NaN        1.3   E10+                NaN
# 16636         0.00           NaN          0     RP                NaN
#
#        mean_user_score  total_sales
# 572               7.55        12.89
# 573               7.55         6.88
# 574               7.55         3.11
# 575               7.55         1.50
# 576               7.55         3.02
# ...                ...          ...
# 16312              NaN         0.06
# 16346              NaN         0.14
# 16448              NaN         0.12
# 16451              NaN         0.06
# 16636              NaN         0.06
#
# [512 rows x 14 columns]

# %%
games_data_3DS_user_score_sales['user_score'].unique()
games_data_3DS_user_score_sales['user_score'] = games_data_3DS_user_score_sales['user_score'].astype('float64')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
games_data_3DS_user_score_sales.plot(x='user_score', y='total_sales', kind='scatter')
plt.show()

# %% [markdown]
# ### По диаграмме рассеяния видно, что продажи начинают расти с пользовательского рейтинга от 5,5, за исключением выброса одной точки с рейтингом около 4,4. Однако с ростом рейтинга большая часть игр все равно имеет низкие продажи

# %%
games_data_3DS_user_score_sales['user_score'].corr(games_data_3DS_user_score_sales['total_sales'])
# Out:
# 0.151715704325732

# %%
games_data_3DS_user_score_sales['critic_score'].corr(games_data_3DS_user_score_sales['total_sales'])
# Out:
# 0.20538892998746297

# %% [markdown]
# ### Вывод
# Значение коэффициента корреляции Пирсона близко к нулю, значит связь слабая, либо отсутствует вовсе. Бывает, что коэффициент нулевой не потому, что связи между значениями нет, а из-за того, что у неё более сложный, не линейный характер. Потому-то коэффициент корреляции такую связь не берёт.
#
# ### То есть связи или нет, или она не линейная.

# %% [markdown]
# ##  Соотнесите выводы с продажами игр на других платформах.

# %%
pd.set_option('display.max_rows', 220)
display(games_data_grouped.groupby('platform').corr())
# Out:
#                             year_of_release  na_sales  eu_sales  jp_sales  \
# platform
# 3DS      year_of_release           1.000000 -0.099383 -0.088037  0.039475
#          na_sales                 -0.099383  1.000000  0.943670  0.664840
#          eu_sales                 -0.088037  0.943670  1.000000  0.686445
#          jp_sales                  0.039475  0.664840  0.686445  1.000000
#          other_sales              -0.095013  0.991024  0.971201  0.672817
#          critic_score              0.165532  0.183328  0.171722  0.198838
#          mean_critic_score         0.211502  0.026279  0.028234  0.118510
#          mean_user_score           0.354248 -0.000562 -0.027230  0.099447
#          total_sales               0.003417  0.796779  0.830491  0.975150
# DC       year_of_release           1.000000 -0.133674 -0.131389 -0.280250
#          na_sales                 -0.133674  1.000000  0.797678  0.098652
#          eu_sales                 -0.131389  0.797678  1.000000  0.333708
#          jp_sales                 -0.280250  0.098652  0.333708  1.000000
#          other_sales              -0.130547  0.875590  0.984311  0.272361
#          critic_score             -0.326339  0.089233 -0.088890 -0.101344
#          mean_critic_score        -0.327557  0.089566 -0.089222 -0.089029
#          mean_user_score          -0.044233 -0.304734 -0.067553  0.340532
#          total_sales              -0.277217  0.368543  0.634273  0.940454
# DS       year_of_release           1.000000 -0.114758 -0.089831 -0.105504
#          na_sales                 -0.114758  1.000000  0.871289  0.687767
#          eu_sales                 -0.089831  0.871289  1.000000  0.688301
#          jp_sales                 -0.105504  0.687767  0.688301  1.000000
#          other_sales              -0.104433  0.935609  0.979990  0.702937
#          critic_score              0.132652  0.142678  0.139714  0.191120
#          mean_critic_score         0.208086 -0.005921  0.011612  0.079984
#          mean_user_score           0.015429  0.005661  0.029511  0.097901
#          total_sales              -0.107728  0.821819  0.876036  0.952810
# GB       year_of_release           1.000000 -0.252789 -0.248568 -0.249652
#          na_sales                 -0.252789  1.000000  0.974412  0.769401
#          eu_sales                 -0.248568  0.974412  1.000000  0.803161
#          jp_sales                 -0.249652  0.769401  0.803161  1.000000
#          other_sales              -0.154192  0.797638  0.790870  0.589585
#          critic_score                   NaN       NaN       NaN       NaN
#          mean_critic_score              NaN       NaN       NaN       NaN
#          mean_user_score                NaN       NaN       NaN       NaN
#          total_sales              -0.260962  0.876888  0.909380  0.978196
# GBA      year_of_release           1.000000 -0.092636 -0.085720 -0.038571
#          na_sales                 -0.092636  1.000000  0.934322  0.666945
#          eu_sales                 -0.085720  0.934322  1.000000  0.746473
#          jp_sales                 -0.038571  0.666945  0.746473  1.000000
#          other_sales              -0.101641  0.910430  0.953685  0.799915
#          critic_score             -0.215402  0.141726  0.122573  0.159751
#          mean_critic_score        -0.337571  0.058660  0.049868  0.153764
#          mean_user_score          -0.259046  0.058150  0.051944  0.136120
#          total_sales              -0.055718  0.790087  0.869830  0.977589
# GC       year_of_release           1.000000 -0.114178 -0.117485 -0.119880
#          na_sales                 -0.114178  1.000000  0.938265  0.724893
#          eu_sales                 -0.117485  0.938265  1.000000  0.649008
#          jp_sales                 -0.119880  0.724893  0.649008  1.000000
#          other_sales              -0.129916  0.968810  0.938659  0.782773
#          critic_score             -0.056365  0.284896  0.268018  0.181867
#          mean_critic_score        -0.102971  0.120464  0.096693  0.106777
#          mean_user_score          -0.044474  0.156620  0.150298  0.178769
#          total_sales              -0.129690  0.868093  0.836101  0.959982
# N64      year_of_release           1.000000 -0.073713 -0.091125  0.032316
#          na_sales                 -0.073713  1.000000  0.850421  0.603469
#          eu_sales                 -0.091125  0.850421  1.000000  0.551918
#          jp_sales                  0.032316  0.603469  0.551918  1.000000
#          other_sales               0.028420  0.558935  0.688248  0.583935
#          critic_score                   NaN       NaN       NaN       NaN
#          mean_critic_score              NaN       NaN       NaN       NaN
#          mean_user_score                NaN       NaN       NaN       NaN
#          total_sales              -0.002418  0.742869  0.748030  0.966280
# PC       year_of_release           1.000000 -0.115482  0.011609 -0.043708
#          na_sales                 -0.115482  1.000000  0.396192  0.256390
#          eu_sales                  0.011609  0.396192  1.000000 -0.009688
#          jp_sales                 -0.043708  0.256390 -0.009688  1.000000
#          other_sales               0.060505  0.413538  0.558882 -0.010594
#          critic_score             -0.198222  0.185783  0.199528  0.065992
#          mean_critic_score        -0.339755  0.110389  0.067229  0.058872
#          mean_user_score          -0.636235  0.018204 -0.038059  0.023477
#          total_sales               0.011003  0.399764  0.999904  0.004184
# PS       year_of_release           1.000000 -0.094095 -0.045131 -0.070168
#          na_sales                 -0.094095  1.000000  0.810637  0.197698
#          eu_sales                 -0.045131  0.810637  1.000000  0.201712
#          jp_sales                 -0.070168  0.197698  0.201712  1.000000
#          other_sales              -0.084271  0.840177  0.932090  0.363927
#          critic_score             -0.424902  0.217378  0.154128  0.159382
#          mean_critic_score        -0.491423  0.119036  0.054917  0.117710
#          mean_user_score          -0.432142  0.066410  0.022992  0.153569
#          total_sales              -0.076909  0.527857  0.617292  0.895078
# PS2      year_of_release           1.000000 -0.154542 -0.205740 -0.105095
#          na_sales                 -0.154542  1.000000  0.664111  0.202004
#          eu_sales                 -0.205740  0.664111  1.000000  0.228208
#          jp_sales                 -0.105095  0.202004  0.228208  1.000000
#          other_sales               0.007861  0.566716  0.305354  0.176649
#          critic_score             -0.135811  0.367155  0.275425  0.203044
#          mean_critic_score        -0.280110  0.084288  0.087918  0.100779
#          mean_user_score          -0.334627  0.099212  0.093434  0.088512
#          total_sales              -0.194918  0.537260  0.758110  0.807926
# PS3      year_of_release           1.000000 -0.146112 -0.068137  0.050052
#          na_sales                 -0.146112  1.000000  0.813041  0.344322
#          eu_sales                 -0.068137  0.813041  1.000000  0.374296
#          jp_sales                  0.050052  0.344322  0.374296  1.000000
#          other_sales              -0.085786  0.872154  0.974571  0.378520
#          critic_score             -0.026496  0.401690  0.333018  0.182616
#          mean_critic_score        -0.052686  0.057187  0.048160  0.051046
#          mean_user_score          -0.239956  0.065787  0.029743  0.121042
#          total_sales              -0.037223  0.781251  0.943286  0.660918
# PS4      year_of_release           1.000000 -0.248961 -0.208306 -0.060993
#          na_sales                 -0.248961  1.000000  0.785362  0.472981
#          eu_sales                 -0.208306  0.785362  1.000000  0.464563
#          jp_sales                 -0.060993  0.472981  0.464563  1.000000
#          other_sales              -0.234796  0.944259  0.944698  0.496467
#          critic_score             -0.044316  0.306781  0.287322  0.254950
#          mean_critic_score        -0.097957  0.056077  0.050302  0.084501
#          mean_user_score           0.244889 -0.151000 -0.123495  0.070581
#          total_sales              -0.200702  0.794705  0.990361  0.582742
# PSP      year_of_release           1.000000 -0.337940 -0.185002  0.068677
#          na_sales                 -0.337940  1.000000  0.702377  0.046502
#          eu_sales                 -0.185002  0.702377  1.000000  0.088238
#          jp_sales                  0.068677  0.046502  0.088238  1.000000
#          other_sales              -0.205894  0.799380  0.965140  0.088916
#          critic_score              0.022076  0.241505  0.214301  0.104379
#          mean_critic_score         0.033687  0.068789  0.047828  0.024586
#          mean_user_score          -0.301413  0.145700  0.089334  0.026197
#          total_sales              -0.008329  0.306188  0.455620  0.926905
# PSV      year_of_release           1.000000 -0.431585 -0.356348 -0.050372
#          na_sales                 -0.431585  1.000000  0.750131  0.128768
#          eu_sales                 -0.356348  0.750131  1.000000  0.209907
#          jp_sales                 -0.050372  0.128768  0.209907  1.000000
#          other_sales              -0.380928  0.868614  0.951343  0.214957
#          critic_score              0.187781 -0.029489  0.079776  0.127158
#          mean_critic_score         0.234612 -0.022441  0.062819  0.083479
#          mean_user_score           0.378330 -0.122799 -0.097987  0.101883
#          total_sales              -0.203163  0.445820  0.624863  0.894504
# SAT      year_of_release           1.000000       NaN       NaN -0.059095
#          na_sales                       NaN       NaN       NaN       NaN
#          eu_sales                       NaN       NaN       NaN       NaN
#          jp_sales                 -0.059095       NaN       NaN  1.000000
#          other_sales                    NaN       NaN       NaN       NaN
#          critic_score                   NaN       NaN       NaN       NaN
#          mean_critic_score              NaN       NaN       NaN       NaN
#          mean_user_score                NaN       NaN       NaN       NaN
#          total_sales              -0.059095       NaN       NaN  1.000000
# SNES     year_of_release           1.000000       NaN       NaN  0.944911
#          na_sales                       NaN       NaN       NaN       NaN
#          eu_sales                       NaN       NaN       NaN       NaN
#          jp_sales                  0.944911       NaN       NaN  1.000000
#          other_sales                    NaN       NaN       NaN       NaN
#          critic_score                   NaN       NaN       NaN       NaN
#          mean_critic_score              NaN       NaN       NaN       NaN
#          mean_user_score                NaN       NaN       NaN       NaN
#          total_sales               0.944911       NaN       NaN  1.000000
# WS       year_of_release           1.000000       NaN       NaN -0.252414
#          na_sales                       NaN       NaN       NaN       NaN
#          eu_sales                       NaN       NaN       NaN       NaN
#          jp_sales                 -0.252414       NaN       NaN  1.000000
#          other_sales                    NaN       NaN       NaN       NaN
#          critic_score                   NaN       NaN       NaN       NaN
#          mean_critic_score              NaN       NaN       NaN       NaN
#          mean_user_score                NaN       NaN       NaN       NaN
#          total_sales              -0.252414       NaN       NaN  1.000000
# Wii      year_of_release           1.000000 -0.085963 -0.064853 -0.052926
#          na_sales                 -0.085963  1.000000  0.971913  0.772618
#          eu_sales                 -0.064853  0.971913  1.000000  0.778595
#          jp_sales                 -0.052926  0.772618  0.778595  1.000000
#          other_sales              -0.082033  0.988362  0.992614  0.771947
#          critic_score              0.205679  0.155490  0.143860  0.181499
#          mean_critic_score         0.398463  0.065652  0.052952  0.073176
#          mean_user_score           0.101162  0.037731  0.026844  0.056249
#          total_sales              -0.063916  0.950101  0.971368  0.905390
# WiiU     year_of_release           1.000000 -0.040385 -0.013585  0.031670
#          na_sales                 -0.040385  1.000000  0.958772  0.808387
#          eu_sales                 -0.013585  0.958772  1.000000  0.860098
#          jp_sales                  0.031670  0.808387  0.860098  1.000000
#          other_sales              -0.014133  0.994516  0.976412  0.824345
#          critic_score              0.049177  0.310177  0.332950  0.254352
#          mean_critic_score         0.083349  0.288306  0.331911  0.330025
#          mean_user_score           0.157923  0.314677  0.362209  0.353934
#          total_sales               0.014766  0.896399  0.945741  0.979182
# X360     year_of_release           1.000000 -0.014709  0.044633 -0.126640
#          na_sales                 -0.014709  1.000000  0.854828  0.486123
#          eu_sales                  0.044633  0.854828  1.000000  0.461634
#          jp_sales                 -0.126640  0.486123  0.461634  1.000000
#          other_sales              -0.004677  0.964488  0.947864  0.501547
#          critic_score             -0.031579  0.360583  0.358613  0.258411
#          mean_critic_score        -0.071289  0.086621  0.088028  0.075263
#          mean_user_score          -0.466014  0.056574  0.047288  0.158684
#          total_sales               0.030002  0.860565  0.996198  0.537163
# XB       year_of_release           1.000000 -0.095788 -0.086095 -0.138754
#          na_sales                 -0.095788  1.000000  0.832848  0.292808
#          eu_sales                 -0.086095  0.832848  1.000000  0.232026
#          jp_sales                 -0.138754  0.292808  0.232026  1.000000
#          other_sales              -0.096109  0.780797  0.843692  0.203059
#          critic_score             -0.022254  0.353497  0.335436  0.108485
#          mean_critic_score        -0.051244  0.129901  0.078325  0.097332
#          mean_user_score          -0.255372  0.094419  0.061682  0.070446
#          total_sales              -0.105460  0.838179  0.985670  0.392784
# XOne     year_of_release           1.000000 -0.242667 -0.194925 -0.127050
#          na_sales                 -0.242667  1.000000  0.765367  0.425725
#          eu_sales                 -0.194925  0.765367  1.000000  0.421071
#          jp_sales                 -0.127050  0.425725  0.421071  1.000000
#          other_sales              -0.243414  0.988088  0.852986  0.441717
#          critic_score              0.099408  0.315801  0.324263  0.191350
#          mean_critic_score         0.167917  0.147435  0.150539  0.101319
#          mean_user_score           0.114045 -0.075775 -0.046699  0.045855
#          total_sales              -0.196116  0.768006  0.999680  0.443867
#
#                             other_sales  critic_score  mean_critic_score  \
# platform
# 3DS      year_of_release      -0.095013      0.165532           0.211502
#          na_sales              0.991024      0.183328           0.026279
#          eu_sales              0.971201      0.171722           0.028234
#          jp_sales              0.672817      0.198838           0.118510
#          other_sales           1.000000      0.183077           0.024962
#          critic_score          0.183077      1.000000           0.782652
#          mean_critic_score     0.024962      0.782652           1.000000
#          mean_user_score      -0.011349      0.573125           0.732287
#          total_sales           0.811278      0.205389           0.099794
# DC       year_of_release      -0.130547     -0.326339          -0.327557
#          na_sales              0.875590      0.089233           0.089566
#          eu_sales              0.984311     -0.088890          -0.089222
#          jp_sales              0.272361     -0.101344          -0.089029
#          other_sales           1.000000     -0.050454          -0.050643
#          critic_score         -0.050454      1.000000           0.996283
#          mean_critic_score    -0.050643      0.996283           1.000000
#          mean_user_score      -0.118703     -0.442247          -0.443897
#          total_sales           0.578304     -0.125432          -0.114690
# DS       year_of_release      -0.104433      0.132652           0.208086
#          na_sales              0.935609      0.142678          -0.005921
#          eu_sales              0.979990      0.139714           0.011612
#          jp_sales              0.702937      0.191120           0.079984
#          other_sales           1.000000      0.141230           0.007491
#          critic_score          0.141230      1.000000           0.637486
#          mean_critic_score     0.007491      0.637486           1.000000
#          mean_user_score       0.020075      0.272236           0.444079
#          total_sales           0.877392      0.185596           0.058140
# GB       year_of_release      -0.154192           NaN                NaN
#          na_sales              0.797638           NaN                NaN
#          eu_sales              0.790870           NaN                NaN
#          jp_sales              0.589585           NaN                NaN
#          other_sales           1.000000           NaN                NaN
#          critic_score               NaN           NaN                NaN
#          mean_critic_score          NaN           NaN                NaN
#          mean_user_score            NaN           NaN                NaN
#          total_sales           0.687355           NaN                NaN
# GBA      year_of_release      -0.101641     -0.215402          -0.337571
#          na_sales              0.910430      0.141726           0.058660
#          eu_sales              0.953685      0.122573           0.049868
#          jp_sales              0.799915      0.159751           0.153764
#          other_sales           1.000000      0.166264           0.098989
#          critic_score          0.166264      1.000000           0.638095
#          mean_critic_score     0.098989      0.638095           1.000000
#          mean_user_score       0.090343      0.432853           0.679062
#          total_sales           0.894799      0.157120           0.129696
# GC       year_of_release      -0.129916     -0.056365          -0.102971
#          na_sales              0.968810      0.284896           0.120464
#          eu_sales              0.938659      0.268018           0.096693
#          jp_sales              0.782773      0.181867           0.106777
#          other_sales           1.000000      0.288913           0.139171
#          critic_score          0.288913      1.000000           0.547380
#          mean_critic_score     0.139171      0.547380           1.000000
#          mean_user_score       0.186447      0.356542           0.658383
#          total_sales           0.909974      0.229407           0.112458
# N64      year_of_release       0.028420           NaN                NaN
#          na_sales              0.558935           NaN                NaN
#          eu_sales              0.688248           NaN                NaN
#          jp_sales              0.583935           NaN                NaN
#          other_sales           1.000000           NaN                NaN
#          critic_score               NaN           NaN                NaN
#          mean_critic_score          NaN           NaN                NaN
#          mean_user_score            NaN           NaN                NaN
#          total_sales           0.677248           NaN                NaN
# PC       year_of_release       0.060505     -0.198222          -0.339755
#          na_sales              0.413538      0.185783           0.110389
#          eu_sales              0.558882      0.199528           0.067229
#          jp_sales             -0.010594      0.065992           0.058872
#          other_sales           1.000000      0.196121           0.017191
#          critic_score          0.196121      1.000000           0.583427
#          mean_critic_score     0.017191      0.583427           1.000000
#          mean_user_score      -0.075305      0.288316           0.495599
#          total_sales           0.558757      0.200463           0.068058
# PS       year_of_release      -0.084271     -0.424902          -0.491423
#          na_sales              0.840177      0.217378           0.119036
#          eu_sales              0.932090      0.154128           0.054917
#          jp_sales              0.363927      0.159382           0.117710
#          other_sales           1.000000      0.204321           0.107229
#          critic_score          0.204321      1.000000           0.864636
#          mean_critic_score     0.107229      0.864636           1.000000
#          mean_user_score       0.084559      0.695556           0.814304
#          total_sales           0.716674      0.197708           0.119274
# PS2      year_of_release       0.007861     -0.135811          -0.280110
#          na_sales              0.566716      0.367155           0.084288
#          eu_sales              0.305354      0.275425           0.087918
#          jp_sales              0.176649      0.203044           0.100779
#          other_sales           1.000000      0.196060           0.009612
#          critic_score          0.196060      1.000000           0.484849
#          mean_critic_score     0.009612      0.484849           1.000000
#          mean_user_score       0.011958      0.236544           0.488164
#          total_sales           0.303138      0.302739           0.120756
# PS3      year_of_release      -0.085786     -0.026496          -0.052686
#          na_sales              0.872154      0.401690           0.057187
#          eu_sales              0.974571      0.333018           0.048160
#          jp_sales              0.378520      0.182616           0.051046
#          other_sales           1.000000      0.348453           0.045931
#          critic_score          0.348453      1.000000           0.502908
#          mean_critic_score     0.045931      0.502908           1.000000
#          mean_user_score       0.041650      0.292932           0.582476
#          total_sales           0.924218      0.334379           0.057126
# PS4      year_of_release      -0.234796     -0.044316          -0.097957
#          na_sales              0.944259      0.306781           0.056077
#          eu_sales              0.944698      0.287322           0.050302
#          jp_sales              0.496467      0.254950           0.084501
#          other_sales           1.000000      0.314029           0.052400
#          critic_score          0.314029      1.000000           0.452407
#          mean_critic_score     0.052400      0.452407           1.000000
#          mean_user_score      -0.142914      0.300884           0.665074
#          total_sales           0.944601      0.303541           0.059376
# PSP      year_of_release      -0.205894      0.022076           0.033687
#          na_sales              0.799380      0.241505           0.068789
#          eu_sales              0.965140      0.214301           0.047828
#          jp_sales              0.088916      0.104379           0.024586
#          other_sales           1.000000      0.217519           0.042128
#          critic_score          0.217519      1.000000           0.655327
#          mean_critic_score     0.042128      0.655327           1.000000
#          mean_user_score       0.098422      0.237685           0.362965
#          total_sales           0.443091      0.173946           0.039975
# PSV      year_of_release      -0.380928      0.187781           0.234612
#          na_sales              0.868614     -0.029489          -0.022441
#          eu_sales              0.951343      0.079776           0.062819
#          jp_sales              0.214957      0.127158           0.083479
#          other_sales           1.000000      0.043756           0.027104
#          critic_score          0.043756      1.000000           0.800388
#          mean_critic_score     0.027104      0.800388           1.000000
#          mean_user_score      -0.100347      0.299767           0.374527
#          total_sales           0.606647      0.137928           0.095359
# SAT      year_of_release            NaN           NaN                NaN
#          na_sales                   NaN           NaN                NaN
#          eu_sales                   NaN           NaN                NaN
#          jp_sales                   NaN           NaN                NaN
#          other_sales                NaN           NaN                NaN
#          critic_score               NaN           NaN                NaN
#          mean_critic_score          NaN           NaN                NaN
#          mean_user_score            NaN           NaN                NaN
#          total_sales                NaN           NaN                NaN
# SNES     year_of_release            NaN           NaN                NaN
#          na_sales                   NaN           NaN                NaN
#          eu_sales                   NaN           NaN                NaN
#          jp_sales                   NaN           NaN                NaN
#          other_sales                NaN           NaN                NaN
#          critic_score               NaN           NaN                NaN
#          mean_critic_score          NaN           NaN                NaN
#          mean_user_score            NaN           NaN                NaN
#          total_sales                NaN           NaN                NaN
# WS       year_of_release            NaN           NaN                NaN
#          na_sales                   NaN           NaN                NaN
#          eu_sales                   NaN           NaN                NaN
#          jp_sales                   NaN           NaN                NaN
#          other_sales                NaN           NaN                NaN
#          critic_score               NaN           NaN                NaN
#          mean_critic_score          NaN           NaN                NaN
#          mean_user_score            NaN           NaN                NaN
#          total_sales                NaN           NaN                NaN
# Wii      year_of_release      -0.082033      0.205679           0.398463
#          na_sales              0.988362      0.155490           0.065652
#          eu_sales              0.992614      0.143860           0.052952
#          jp_sales              0.771947      0.181499           0.073176
#          other_sales           1.000000      0.141594           0.056403
#          critic_score          0.141594      1.000000           0.516180
#          mean_critic_score     0.056403      0.516180           1.000000
#          mean_user_score       0.031591      0.290915           0.564633
#          total_sales           0.963853      0.165748           0.063410
# WiiU     year_of_release      -0.014133      0.049177           0.083349
#          na_sales              0.994516      0.310177           0.288306
#          eu_sales              0.976412      0.332950           0.331911
#          jp_sales              0.824345      0.254352           0.330025
#          other_sales           1.000000      0.323559           0.310148
#          critic_score          0.323559      1.000000           0.590016
#          mean_critic_score     0.310148      0.590016           1.000000
#          mean_user_score       0.341892      0.475601           0.806080
#          total_sales           0.913583      0.294205           0.341823
# X360     year_of_release      -0.004677     -0.031579          -0.071289
#          na_sales              0.964488      0.360583           0.086621
#          eu_sales              0.947864      0.358613           0.088028
#          jp_sales              0.501547      0.258411           0.075263
#          other_sales           1.000000      0.380329           0.090451
#          critic_score          0.380329      1.000000           0.442971
#          mean_critic_score     0.090451      0.442971           1.000000
#          mean_user_score       0.065262      0.251955           0.568783
#          total_sales           0.950544      0.366428           0.091109
# XB       year_of_release      -0.096109     -0.022254          -0.051244
#          na_sales              0.780797      0.353497           0.129901
#          eu_sales              0.843692      0.335436           0.078325
#          jp_sales              0.203059      0.108485           0.097332
#          other_sales           1.000000      0.399601           0.149594
#          critic_score          0.399601      1.000000           0.434279
#          mean_critic_score     0.149594      0.434279           1.000000
#          mean_user_score       0.110647      0.304369           0.710405
#          total_sales           0.832868      0.335947           0.090931
# XOne     year_of_release      -0.243414      0.099408           0.167917
#          na_sales              0.988088      0.315801           0.147435
#          eu_sales              0.852986      0.324263           0.150539
#          jp_sales              0.441717      0.191350           0.101319
#          other_sales           1.000000      0.333091           0.153038
#          critic_score          0.333091      1.000000           0.592006
#          mean_critic_score     0.153038      0.592006           1.000000
#          mean_user_score      -0.074289      0.359839           0.607829
#          total_sales           0.855015      0.325640           0.151525
#
#                             mean_user_score  total_sales
# platform
# 3DS      year_of_release           0.354248     0.003417
#          na_sales                 -0.000562     0.796779
#          eu_sales                 -0.027230     0.830491
#          jp_sales                  0.099447     0.975150
#          other_sales              -0.011349     0.811278
#          critic_score              0.573125     0.205389
#          mean_critic_score         0.732287     0.099794
#          mean_user_score           1.000000     0.067756
#          total_sales               0.067756     1.000000
# DC       year_of_release          -0.044233    -0.277217
#          na_sales                 -0.304734     0.368543
#          eu_sales                 -0.067553     0.634273
#          jp_sales                  0.340532     0.940454
#          other_sales              -0.118703     0.578304
#          critic_score             -0.442247    -0.125432
#          mean_critic_score        -0.443897    -0.114690
#          mean_user_score           1.000000     0.273431
#          total_sales               0.273431     1.000000
# DS       year_of_release           0.015429    -0.107728
#          na_sales                  0.005661     0.821819
#          eu_sales                  0.029511     0.876036
#          jp_sales                  0.097901     0.952810
#          other_sales               0.020075     0.877392
#          critic_score              0.272236     0.185596
#          mean_critic_score         0.444079     0.058140
#          mean_user_score           1.000000     0.077526
#          total_sales               0.077526     1.000000
# GB       year_of_release                NaN    -0.260962
#          na_sales                       NaN     0.876888
#          eu_sales                       NaN     0.909380
#          jp_sales                       NaN     0.978196
#          other_sales                    NaN     0.687355
#          critic_score                   NaN          NaN
#          mean_critic_score              NaN          NaN
#          mean_user_score                NaN          NaN
#          total_sales                    NaN     1.000000
# GBA      year_of_release          -0.259046    -0.055718
#          na_sales                  0.058150     0.790087
#          eu_sales                  0.051944     0.869830
#          jp_sales                  0.136120     0.977589
#          other_sales               0.090343     0.894799
#          critic_score              0.432853     0.157120
#          mean_critic_score         0.679062     0.129696
#          mean_user_score           1.000000     0.117181
#          total_sales               0.117181     1.000000
# GC       year_of_release          -0.044474    -0.129690
#          na_sales                  0.156620     0.868093
#          eu_sales                  0.150298     0.836101
#          jp_sales                  0.178769     0.959982
#          other_sales               0.186447     0.909974
#          critic_score              0.356542     0.229407
#          mean_critic_score         0.658383     0.112458
#          mean_user_score           1.000000     0.183757
#          total_sales               0.183757     1.000000
# N64      year_of_release                NaN    -0.002418
#          na_sales                       NaN     0.742869
#          eu_sales                       NaN     0.748030
#          jp_sales                       NaN     0.966280
#          other_sales                    NaN     0.677248
#          critic_score                   NaN          NaN
#          mean_critic_score              NaN          NaN
#          mean_user_score                NaN          NaN
#          total_sales                    NaN     1.000000
# PC       year_of_release          -0.636235     0.011003
#          na_sales                  0.018204     0.399764
#          eu_sales                 -0.038059     0.999904
#          jp_sales                  0.023477     0.004184
#          other_sales              -0.075305     0.558757
#          critic_score              0.288316     0.200463
#          mean_critic_score         0.495599     0.068058
#          mean_user_score           1.000000    -0.037732
#          total_sales              -0.037732     1.000000
# PS       year_of_release          -0.432142    -0.076909
#          na_sales                  0.066410     0.527857
#          eu_sales                  0.022992     0.617292
#          jp_sales                  0.153569     0.895078
#          other_sales               0.084559     0.716674
#          critic_score              0.695556     0.197708
#          mean_critic_score         0.814304     0.119274
#          mean_user_score           1.000000     0.133035
#          total_sales               0.133035     1.000000
# PS2      year_of_release          -0.334627    -0.194918
#          na_sales                  0.099212     0.537260
#          eu_sales                  0.093434     0.758110
#          jp_sales                  0.088512     0.807926
#          other_sales               0.011958     0.303138
#          critic_score              0.236544     0.302739
#          mean_critic_score         0.488164     0.120756
#          mean_user_score           1.000000     0.115821
#          total_sales               0.115821     1.000000
# PS3      year_of_release          -0.239956    -0.037223
#          na_sales                  0.065787     0.781251
#          eu_sales                  0.029743     0.943286
#          jp_sales                  0.121042     0.660918
#          other_sales               0.041650     0.924218
#          critic_score              0.292932     0.334379
#          mean_critic_score         0.582476     0.057126
#          mean_user_score           1.000000     0.067423
#          total_sales               0.067423     1.000000
# PS4      year_of_release           0.244889    -0.200702
#          na_sales                 -0.151000     0.794705
#          eu_sales                 -0.123495     0.990361
#          jp_sales                  0.070581     0.582742
#          other_sales              -0.142914     0.944601
#          critic_score              0.300884     0.303541
#          mean_critic_score         0.665074     0.059376
#          mean_user_score           1.000000    -0.102292
#          total_sales              -0.102292     1.000000
# PSP      year_of_release          -0.301413    -0.008329
#          na_sales                  0.145700     0.306188
#          eu_sales                  0.089334     0.455620
#          jp_sales                  0.026197     0.926905
#          other_sales               0.098422     0.443091
#          critic_score              0.237685     0.173946
#          mean_critic_score         0.362965     0.039975
#          mean_user_score           1.000000     0.057066
#          total_sales               0.057066     1.000000
# PSV      year_of_release           0.378330    -0.203163
#          na_sales                 -0.122799     0.445820
#          eu_sales                 -0.097987     0.624863
#          jp_sales                  0.101883     0.894504
#          other_sales              -0.100347     0.606647
#          critic_score              0.299767     0.137928
#          mean_critic_score         0.374527     0.095359
#          mean_user_score           1.000000     0.036115
#          total_sales               0.036115     1.000000
# SAT      year_of_release                NaN    -0.059095
#          na_sales                       NaN          NaN
#          eu_sales                       NaN          NaN
#          jp_sales                       NaN     1.000000
#          other_sales                    NaN          NaN
#          critic_score                   NaN          NaN
#          mean_critic_score              NaN          NaN
#          mean_user_score                NaN          NaN
#          total_sales                    NaN     1.000000
# SNES     year_of_release                NaN     0.944911
#          na_sales                       NaN          NaN
#          eu_sales                       NaN          NaN
#          jp_sales                       NaN     1.000000
#          other_sales                    NaN          NaN
#          critic_score                   NaN          NaN
#          mean_critic_score              NaN          NaN
#          mean_user_score                NaN          NaN
#          total_sales                    NaN     1.000000
# WS       year_of_release                NaN    -0.252414
#          na_sales                       NaN          NaN
#          eu_sales                       NaN          NaN
#          jp_sales                       NaN     1.000000
#          other_sales                    NaN          NaN
#          critic_score                   NaN          NaN
#          mean_critic_score              NaN          NaN
#          mean_user_score                NaN          NaN
#          total_sales                    NaN     1.000000
# Wii      year_of_release           0.101162    -0.063916
#          na_sales                  0.037731     0.950101
#          eu_sales                  0.026844     0.971368
#          jp_sales                  0.056249     0.905390
#          other_sales               0.031591     0.963853
#          critic_score              0.290915     0.165748
#          mean_critic_score         0.564633     0.063410
#          mean_user_score           1.000000     0.039364
#          total_sales               0.039364     1.000000
# WiiU     year_of_release           0.157923     0.014766
#          na_sales                  0.314677     0.896399
#          eu_sales                  0.362209     0.945741
#          jp_sales                  0.353934     0.979182
#          other_sales               0.341892     0.913583
#          critic_score              0.475601     0.294205
#          mean_critic_score         0.806080     0.341823
#          mean_user_score           1.000000     0.369081
#          total_sales               0.369081     1.000000
# X360     year_of_release          -0.466014     0.030002
#          na_sales                  0.056574     0.860565
#          eu_sales                  0.047288     0.996198
#          jp_sales                  0.158684     0.537163
#          other_sales               0.065262     0.950544
#          critic_score              0.251955     0.366428
#          mean_critic_score         0.568783     0.091109
#          mean_user_score           1.000000     0.060552
#          total_sales               0.060552     1.000000
# XB       year_of_release          -0.255372    -0.105460
#          na_sales                  0.094419     0.838179
#          eu_sales                  0.061682     0.985670
#          jp_sales                  0.070446     0.392784
#          other_sales               0.110647     0.832868
#          critic_score              0.304369     0.335947
#          mean_critic_score         0.710405     0.090931
#          mean_user_score           1.000000     0.070548
#          total_sales               0.070548     1.000000
# XOne     year_of_release           0.114045    -0.196116
#          na_sales                 -0.075775     0.768006
#          eu_sales                 -0.046699     0.999680
#          jp_sales                  0.045855     0.443867
#          other_sales              -0.074289     0.855015
#          critic_score              0.359839     0.325640
#          mean_critic_score         0.607829     0.151525
#          mean_user_score           1.000000    -0.044858
#          total_sales              -0.044858     1.000000

# %% [markdown]
# ### В некоторых платформах есть слабая связь между user_score и na_sales и eu_sales - от 0.33 до 0.4.
# Сильной связи рейтингов и продаж не наблюдается

# %% [markdown]
# ## 3.6 Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %%
games_data_genre_sales = games_data_grouped.pivot_table(index='genre', values='total_sales', aggfunc='sum')
games_data_genre_sales.reset_index()

games_data_genre_sales['total_sales'].sort_values(ascending=False)
# Out:
# genre
# Action          768.52
# Role-Playing    716.78
# Sports          532.36
# Misc            388.61
# Shooter         348.97
# Racing          279.53
# Platform        273.97
# Simulation      206.08
# Fighting        188.76
# Adventure       137.52
# Strategy        116.61
# Puzzle           93.87
# Name: total_sales, dtype: float64

# %% [markdown]
# ### Да, жанр явно влияет на прибыльность.
# Жанры в порядке убывания в верхней половине диапазона продаж:
#
# * Action          768.52
# * Role-Playing    716.78
# * Sports          532.36
# * Misc            388.61
# * Shooter         348.97
# * Racing          279.53

# %% [markdown]
# ## Шаг 4. Составьте портрет пользователя каждого региона
# Определите для пользователя каждого региона (NA, EU, JP):
# Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# Самые популярные жанры (топ-5). Поясните разницу.
# Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %%
games_data_na_sales = games_data_grouped.pivot_table(index='platform', values='na_sales', aggfunc='sum')
games_data_na_sales.reset_index()

na = games_data_na_sales.sort_values(by='na_sales', ascending=False).head(5)

na.plot(kind='pie', subplots=True, autopct='%1.1f%%')
plt.show()

# %%
games_data_eu_sales = games_data_grouped.pivot_table(index='platform', values='eu_sales', aggfunc='sum')
games_data_eu_sales.reset_index()

eu = games_data_eu_sales.sort_values(by='eu_sales', ascending=False).head(5)

eu.plot(kind='pie', subplots=True, autopct='%1.1f%%')
plt.show()

# %%
games_data_jp_sales = games_data_grouped.pivot_table(index='platform', values='jp_sales', aggfunc='sum')
games_data_jp_sales.reset_index()

jp = games_data_jp_sales.sort_values(by='jp_sales', ascending=False).head(5)
jp.plot(kind='pie', subplots=True, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ### Портрет пользователя по региону
#
# регион NA, Топ-5 популярных платформ их распределение долей продаж в них:
# X360 (24,6%), PS3(23,8%), Wii(20,1%), PS3 (16,1%), DS (15,7%)
#
# регион eu , Топ-5 популярных платформ их распределение долей продаж в них:
# PS2 (24,2%) , PS3(23,8%), X360(19,5%), Wii (18,8%), DS (13,7%)
#
# регион jp, Топ-5 популярных платформ их распределение долей продаж в них:
# DS (30,7%), PS2 (24,2%), 3DS (17,7%), PS3 (14%), PS (13,5%)

# %% [markdown]
# ### Самые популярные жанры (топ-5). Поясните разницу.

# %%
games_data_na_sales_2 = games_data_grouped.pivot_table(index='genre', values='na_sales', aggfunc='sum')
games_data_na_sales_2.reset_index()

na_2 = games_data_na_sales_2.sort_values(by='na_sales', ascending=False).head(5)

na_2.plot(kind='pie', subplots=True, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ## В na больше всего играют в жанры:
# * ACtions
# * Sports
# * Shooter
# * Misc
# * Roleplay

# %%
games_data_eu_sales_2 = games_data_grouped.pivot_table(index='genre', values='eu_sales', aggfunc='sum')
games_data_eu_sales_2.reset_index()

eu_2 = games_data_eu_sales_2.sort_values(by='eu_sales', ascending=False).head(5)

eu_2.plot(kind='pie', subplots=True, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ## В eu больше всего играют в жанры:
# * ACtions
# * Sports
# * Shooter
# * Racing
# * Misc

# %%
games_data_jp_sales_2 = games_data_grouped.pivot_table(index='genre', values='jp_sales', aggfunc='sum')
games_data_jp_sales_2.reset_index()

jp_2 = games_data_jp_sales_2.sort_values(by='jp_sales', ascending=False).head(5)

jp_2.plot(kind='pie', subplots=True, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ## В jp больше всего играют в жанры:
# * Roleplay
# * ACtions
# * Misc
# * Sports
# * Platform

# %% [markdown]
# ### Влияет ли рейтинг ESRB на продажи в отдельном регионе?
# Построить табличку: по строкам рейтинг, по столбцам – регион. В ячейках – доля продаж игр с таким рейтингом в регионе. (например). Собственно говоря, искать паттерны: игры с более высоким рейтингом лучше продаются во всех регионах или нет.

# %%
games_data_platform_region_sales = (games_data_grouped
                             .pivot_table(index='rating', values=('na_sales', 'eu_sales', 'jp_sales'), aggfunc='sum'))
games_data_platform_region_sales.reset_index()
# Out:
#   rating  eu_sales  jp_sales  na_sales
# 0     AO      0.61      0.00      1.26
# 1      E    698.86    195.13   1268.23
# 2   E10+    183.33     40.20    345.50
# 3     EC      0.11      0.00      1.53
# 4      M    476.55     62.11    734.87
# 5     RP    445.23    478.10    698.28
# 6      T    410.49    142.66    734.36

# %% [markdown]
# ### Влияние рейтинга ESBR на продажи в регионе:
# рейтинг явно влияет на продажи в регионе
# Считаем плохими продажам до 1, низкими продажами до 200, средними до 500, высокими свыше 500
# * AO и EC плохо продается во всех регионах
# * E плохо продается в jp, хорошо - в eu, и в 2 раза лучше в na
# * E10+ имеет небольшие продажи в jp - 40, в 4 раза выше в eu, и почти на порядок выше в na
# * M имеет низкие продажи в jp, хорошие продажи в eu (476), высокие в na
# * RP имеет хорошие продажи в eu и jp, высокие в na
# * T имеет невысокие продажи в jp, хорошие в eu и высокие в na

# %% [markdown]
# ## Шаг 5. Проверьте гипотезы
# Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# Средние пользовательские рейтинги жанров Action (англ. «действие») и Sports (англ. «виды спорта») разные.
# Задайте самостоятельно пороговое значение alpha.
# Поясните:
# Как вы сформулировали нулевую и альтернативную гипотезы;
# Какой критерий применили для проверки гипотез и почему.

# %% [markdown]
# ## Гипотеза 1. Средние пользовательские рейтинги платформ Xbox One и PC одинаковые

# %% [markdown]
# * Нулевая гипотеза: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
# * Альтернативная гипотеза: Средние пользовательские рейтинги платформ Xbox One и PC разные.
# Критерий st.ttest_ind так как выборки из одной генеральной совокупности.
# Если p-value- меньше порогового значения, то нулевая гипотеза отвергается. Иначе - не отвергается.

# %%
games_data_grouped['user_score'] = games_data_grouped['user_score'].astype('float64')
xone = games_data_grouped.query('platform == "XOne"')['user_score'].dropna()
pc = games_data_grouped.query('platform == "PC"')['user_score'].dropna()

alpha = 0.05
results = st.ttest_ind(xone, pc, nan_policy='omit', equal_var=True) 

print('p-value:', results.pvalue)
 
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу. Средний рейтинг разный")
else:
    print("Не получилось отвергнуть нулевую гипотезу. Средний рейтинг не отличается")
# Out:
# p-value: 0.00315810298659983
# Отвергаем нулевую гипотезу. Средний рейтинг разный

# %% [markdown]
# ## Гипотеза 2. Средние пользовательские рейтинги жанров Action (англ. «действие») и Sports (англ. «виды спорта») разные.

# %% [markdown]
# * Нулевая гипотеза: средний пользовательский рейтинг жанров Actions и Sports не отличается.
# * Альтернативная гипотеза: средний пользовательский рейтинг жанров Actions и Sports отличается.
# Критерий st.ttest_ind так как выборки из одной генеральной совокупности.
# Если p-value- меньше порогового значения, то нулевая гипотеза отвергается. Иначе - не отвергается.

# %%
games_data_grouped['user_score'] = games_data_grouped['user_score'].astype('float64')
action = games_data_grouped.query('genre == "Action"')['user_score']
sports = games_data_grouped.query('genre == "Sports"')['user_score']

# %%
alpha = 0.05

results = st.ttest_ind(action, sports, nan_policy='omit', equal_var=True)
print('p-value', results.pvalue)
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу. Средний рейтинг разный')
else:
    print('Не получилось отвергнуть нулевую гипотезу. Средний рейтинг не отличается')
# Out:
# p-value 7.540345938651323e-10
# Отвергаем нулевую гипотезу. Средний рейтинг разный

# %% [markdown]
# # Общий вывод
# ## Описание проекта
#
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# ### Шаг 1. Получен датасет
# Был проведен анализ датасета на 16 тысяч строк с информацией о компьютерных играх магазина. Датасет содержит инфромацию об играх начиная с 1980 года.
# Описание данных
# * Name — название игры
# * Platform — платформа
# * Year_of_Release — год выпуска
# * Genre — жанр игры
# * NA_sales — продажи в Северной Америке (миллионы долларов)
# * EU_sales — продажи в Европе (миллионы долларов)
# * JP_sales — продажи в Японии (миллионы долларов)
# * Other_sales — продажи в других странах (миллионы долларов)
# * Critic_Score — оценка критиков (максимум 100)
# * User_Score — оценка пользователей (максимум 10)
# * Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# ### Шаг 2. Подготовили данные
#
# Преобразованы строковые данные в численные типы для расчетов.
# Датасет содержал значимое количество пропусков:
# * critic_score       8578
# * rating             6766
# * user_score         6701
# * year_of_release     269
#
# ---
# * Заполнены отсутствующие значения по critic_score, rating и user_score средними значениями там, где хватило на это данных.
# * year_of_release заполнен нулями, так как вводных из данных для заполнения найдено не было.
#
# ---
# Возможные причины, которые могли привести к пропускам critic_score, user_score и rating:
# * игра старая, и в то время рейтинги еще не собирали
# * игра новая и не собрала рейтинги
# * игра еще не запущена
# * игра не набрала оценок для рейтинга
#
# Была обработана аббревиатура 'tbd' в столбцах с рейтингом:
# TBD расшифровывается как будет объявлено позже.
# Анализ показал, что игры с рейтингом tbd были выпущены, критики их оценили, а вот зрители - нет. И продажи таких игр ниже в 2-4 раза в разных странах. Сделаем предположение, что это непопулярные игры.
# Проставили им минимальный рейтинг по user_score из датасета без значения tbd.
#
# Также посчитали суммарные продажи во всех регионах и записали в отдельный столбец total_sales.
#
# ### Шаг 3. Провели исследовательский анализ данных
# Значительный прирост игр можно отметить с 1998 года Вырезали данные за годы ранее 1998 из датасета как наименее важные для задачи.
# Продажи по самым популярным платформам менялись следующим образом:
# ![image.png](attachment:image.png)
# Средний срок жизни платформы - от 7 до 12 лет
#
# ---
# Лидируют по продажам на промежутке времени с 1998 года по 2016:
# * PS, PS2, DS, Wiiб PS3
#
# Падают на конец 2016:
# * 3DS, PS3, PS4, Wii, X360
#
# Растущих платформ нет
#
# Потенциально прибыльные платформы с остаточной прибылью:
# * 3DS, PS4, еще немного прибыли можно получить с PS3
#
# ---
# Разница а продажах платформ есть. Можно выделить 4 крупные по продажам платформы:
# * PS, PS2, DS, Wii
#
# 3 платформы поменьше:
# * GBA, PS3, X360
#
# и 3 совсем маленькие платформы:
# * 3DS, PS4, PSP
#
# ---
# В средних продажах разница не так велика.
# В нижней части диапазона средних продаж находятся платформы:
# * GBA, PSP, Wii, X360
#
# В верхней части диапазона находится платформа DS
#
# Все остальные платформы в середине диапазона на близких друг к другу средних значениях продаж
#
# ---
# Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков.
#
# * По диаграмме рассеяния видно, что продажи начинают расти с пользовательского рейтинга от 5,5, за исключением выброса одной точки с рейтингом около 4,4. Однако с ростом рейтинга большая часть игр все равно имеет низкие продажи
# * Значение коэффициента корреляции Пирсона близко к нулю, значит связь слабая, либо отсутствует вовсе. Бывает, что коэффициент нулевой не потому, что связи между значениями нет, а из-за того, что у неё более сложный, не линейный характер. Потому-то коэффициент корреляции такую связь не берёт. То есть связи или нет, или она не линейная.
#
# ---
# В некоторых платформах есть слабая корреляция между user_score и na_sales и eu_sales - от 0.33 до 0.4. Сильной связи рейтингов и продаж не наблюдается
#
# ---
#
# Жанр явно влияет на прибыльность игры.
# Жанры в порядке убывания в верхней половине диапазона продаж:
#
# * Action          768.52
# * Role-Playing    716.78
# * Sports          532.36
# * Misc            388.61
# * Shooter         348.97
# * Racing          279.53
#
# ### Шаг 4. Составлен портрет пользователя каждого региона
#
# Топ-5 самых популярных платформ  по региону с распределением продаж по долям:
#
# регион NA
# * X360 (24,6%), PS3(23,8%), Wii(20,1%), PS3 (16,1%), DS (15,7%)
#
# регион eu
# * PS2 (24,2%) , PS3(23,8%), X360(19,5%), Wii (18,8%), DS (13,7%)
#
# регион jp
# * DS (30,7%), PS2 (24,2%), 3DS (17,7%), PS3 (14%), PS (13,5%)
#
# ---
# Топ-5 самых популярных жанров по региону
# регион na:
# * ACtions
# * Sports
# * Shooter
# * Misc
# * Roleplay
#
# регион eu:
# * ACtions
# * Sports
# * Shooter
# * Racing
# * Misc
#
# регион jp:
# * Roleplay
# * ACtions
# * Misc
# * Sports
# * Platform
#
# Отличия могут быть продиктованы культурными и соцдесм различиями в регионе.
#
# ---
# Рейтинг ESBR явно влияет на продажи в регионе.
# Считаем плохими продажам до 1, низкими продажами до 200, средними до 500, высокими свыше 500
# * AO и EC плохо продается во всех регионах
# * E плохо продается в jp, хорошо - в eu, и в 2 раза лучше в na
# * E10+ имеет небольшие продажи в jp - 40, в 4 раза выше в eu, и почти на порядок выше в na
# * M имеет низкие продажи в jp, хорошие продажи в eu (476), высокие в na
# * RP имеет хорошие продажи в eu и jp, высокие в na
# * T имеет невысокие продажи в jp, хорошие в eu и высокие в na
#
#
# ## Общий вывод. Рекомендации для развития игр на 2017 год:
# * делать игры для потенциально прибыльных платформ с остаточной прибылью: 3DS, PS4, еще немного прибыли можно получить с PS3
# * запланировать выпуск новых платформ, так как текущие находятся в упадке и пользователю скоро потребуется замена.
# * в выборе направлений развития новых платформ можно учесть и особенности текущих популярных платформ, и особенности и знания о самых продаваемых платформах вообще (PS, PS2, DS, Wii)
# * учесть особенности платформы ds - в средних значенияз продаж она находилась верхней части диапазона находится платформа DS
# ---
# учесть региональные предпочтения по платформам:
# * в регионе NA наиболее популярны платформы: X360 (24,6%), PS3(23,8%), Wii(20,1%), PS3 (16,1%), DS (15,7%)
# * в регионе EU наиболее популярны платформы: PS2 (24,2%) , PS3(23,8%), X360(19,5%), Wii (18,8%), DS (13,7%)
# * в регионе JP наиболее популярны платформы: DS (30,7%), PS2 (24,2%), 3DS (17,7%), PS3 (14%), PS (13,5%)
# ---
# учесть данные о том, какие жанры наиболее прибыльные в каждом регионе:
# * регион na: ACtions, Sports, Shooter, Misc, Roleplay
# * регион eu: ACtions, Sports, Shooter, Racing, Misc
# * регион jp: Roleplay, ACtions, Misc, Sports, Platform
# ---
# рекомендовано развивать игры с указанным рейтингом ESRB в следующих регионах:
# * E - в регионе na, во вторую очередь - в регионе eu
# * E10+ - в регионе na, во вторую очередь - в регионе eu
# * M - в регионе na, во вторую очередь в регионе eu
# * RP - в регионе na, во вторую очередь в eu и jp
# * T - в регионе na, во вторую очередь в регионе eu.
# ---
# * также можно в развитии игр помнить, что пользовательский рейтинг может слабо влиять на продажи в регионах na и ru
